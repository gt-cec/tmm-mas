# %%
import asyncio
import websockets

async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        # Receive one row of data from the server
        data_from_server = await websocket.recv()
        
        # Print the raw data received from the server
        print(f"Raw data received from server: {data_from_server}")
        
        # Parse the received data (convert string to list)
        row = eval(data_from_server)  # Convert string back to list
        
        # Extract data from the row
        first_state = int(row[1])
        second_state = int(row[2])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining  # timestep + steps_remaining
        
        # Append the processed data to SHMM-like structure
        shmm_data = [[timestep, first_state, second_state, steps_remaining, mission_time]]
        
        # Convert the processed data into the hmm_array format
        hmm_array = [timestep, first_state, second_state, round(float(row[3]), 2), 37]  # 37 as a constant value
        
        # Print the converted hmm_array
        print(f"Converted to hmm_array: {hmm_array}")
        
        # Send a confirmation message back to the server
        await websocket.send("Data received and processed")
        
        # Stop after processing the first row
        print("Processing completed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Converted to hmm_array: [0, 4, 3, 10.0, 37]
# Processing completed. Stopping client.

# %%
import asyncio
import websockets
import numpy as np

# Adjusted RMM array generation for a single row of SHMM data
def generate_rmm_array_for_row(shmm_row):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row
    rmm_array = [position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

# Client-side WebSocket logic
async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        # Receive one row of data from the server
        data_from_server = await websocket.recv()
        
        # Print the raw data received from the server
        print(f"Raw data received from server: {data_from_server}")
        
        # Parse the received data (convert string to list)
        row = eval(data_from_server)  # Convert string back to list
        
        # Extract data from the row
        first_state = int(row[1])
        second_state = int(row[2])
        time_elapsed = float(row[3])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining
        
        # Prepare the SHMM data tuple for a single row
        shmm_row = ((first_state, second_state), time_elapsed, mission_time)

        # Generate RMM array for the current row
        rmm_array = generate_rmm_array_for_row(shmm_row)
        
        # Convert the current processed row into HMM array format
        hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]  # 37 as constant
        
        # Print the generated RMM and HMM arrays
        print(f"Generated RMM array for row: {rmm_array}")
        print(f"Generated HMM array for row: {hmm_array}")
        
        # Send a confirmation message back to the server
        await websocket.send("Data received and processed")
        
        # Stop after processing the first row
        print("Processing completed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Generated RMM array for row: [4, 3, 9.98, 48]
# Generated HMM array for row: [0, 4, 3, 10.0, 37]
# Processing completed. Stopping client.

# %%
import asyncio
import websockets
import numpy as np

# Adjusted RMM array generation for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

# Client-side WebSocket logic
async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        # Receive one row of data from the server
        data_from_server = await websocket.recv()
        
        # Print the raw data received from the server
        print(f"Raw data received from server: {data_from_server}")
        
        # Parse the received data (convert string to list)
        row = eval(data_from_server)  # Convert string back to list
        
        # Extract data from the row
        first_state = int(row[1])
        second_state = int(row[2])
        time_elapsed = float(row[3])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining
        
        # Prepare the SHMM data tuple for a single row
        shmm_row = ((first_state, second_state), time_elapsed, mission_time)

        # Generate RMM array for the current row (with index)
        rmm_array = generate_rmm_array_for_row(shmm_row, timestep)
        
        # Convert the current processed row into HMM array format (with index)
        hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]  # 37 as constant
        
        # Print the generated RMM and HMM arrays
        print(f"Generated RMM array for row: {rmm_array}")
        print(f"Generated HMM array for row: {hmm_array}")
        
        # Send a confirmation message back to the server
        await websocket.send("Data received and processed")
        
        # Stop after processing the first row
        print("Processing completed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Generated RMM array for row: [0, 4, 3, 13.87, 48]
# Generated HMM array for row: [0, 4, 3, 10.0, 37]
# Processing completed. Stopping client.

# %%
import asyncio
import websockets
import numpy as np

# Global variables to store the arrays
hmm_array = None
rmm_array = None

# Adjusted RMM array generation for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

# Client-side WebSocket logic
async def websocket_client():
    global hmm_array, rmm_array  # Declare global variables
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        # Receive one row of data from the server
        data_from_server = await websocket.recv()
        
        # Print the raw data received from the server
        print(f"Raw data received from server: {data_from_server}")
        
        # Parse the received data (convert string to list)
        row = eval(data_from_server)  # Convert string back to list
        
        # Extract data from the row
        first_state = int(row[1])
        second_state = int(row[2])
        time_elapsed = float(row[3])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining
        
        # Prepare the SHMM data tuple for a single row
        shmm_row = ((first_state, second_state), time_elapsed, mission_time)

        # Generate RMM array for the current row (with index)
        rmm_array = generate_rmm_array_for_row(shmm_row, timestep)
        
        # Convert the current processed row into HMM array format (with index)
        hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]  # 37 as constant
        
        # Print the generated RMM and HMM arrays
        print(f"Generated RMM array for row: {rmm_array}")
        print(f"Generated HMM array for row: {hmm_array}")
        
        # Send a confirmation message back to the server
        await websocket.send("Data received and processed")
        
        # Stop after processing the first row
        print("Processing completed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Generated RMM array for row: [0, 5, 3, 5.65, 48]
# Generated HMM array for row: [0, 4, 3, 10.0, 37]
# Processing completed. Stopping client.

# %%
hmm_array
# Out:
# [0, 4, 3, 10.0, 37]

# %%
rmm_array
# Out:
# [0, 4, 3, 12.45, 48]

# %%
import numpy as np

# Define the uncertainty factors
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    # Calculate the L1 norm (absolute difference)
    norm = np.abs(np.array(array2) - np.array(array1))
    return norm

# Function to perform a Bayesian probabilistic update
def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value


# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template


def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        # print(delay_message)
        messages.append(delay_message)  # Append formatted delay message to messages list
        # print(messages)
    return messages





# Function to dynamically update based on deviations and given logics
def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    updated_hmm_array = []  # Initialize updated_hmm_array
    current_hmm_mission_time = hmm_arrays[0][4]  # Use the mission time from hmm_arrays

    # Print the current mission time for debugging
    print("Current HMM Mission Time:", current_hmm_mission_time)

    # Use the updated position from rmm
    updated_pos1 = rmm_arrays[0][1]  # First position from rmm
    updated_pos2 = rmm_arrays[0][2]  # Second position from rmm

    # Calculate the mission time deviation
    mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[0][4]])
    print("Mission Time Deviation:", mission_time_deviation)
    
    # Get the first element of the deviation for updating
    mission_time_deviation_value = mission_time_deviation[0]

    # Set a dynamic threshold for mission time
    dynamic_threshold_mission_time = 2



    hmm_pos1 = hmm_arrays[0][1]
    hmm_pos2 = hmm_arrays[0][2]
    rmm_pos1 = rmm_arrays[0][1]
    rmm_pos2 = rmm_arrays[0][2]
    hmm_time = hmm_arrays[0][3]
    rmm_time = rmm_arrays[0][3]

    message = generate_communication_message(mission_time_deviation_value, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)


    
    # Update mission time using the update logic
    updated_mission_time = update_logic_functions[0](current_hmm_mission_time, mission_time_deviation_value,
                                                       dynamic_threshold_mission_time, uncertainty_factor_time)
    print("Updated Mission Time:", updated_mission_time)

    # Append the updated values to the updated_hmm_array
    updated_hmm_array.append([0, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

    return updated_hmm_array, message



# Define the update logics
update_logics = [bayesian_probabilistic_update_general]

# Call the function
updated_hmm_array, message = dynamic_deviation_threshold_multi_logic(
    [hmm_array], [rmm_array], update_logics, uncertainty_factor_pos, uncertainty_factor_time
)

print(" HMM Array:", hmm_array)
print(" RMM Array:", rmm_array)


# Print the updated hmm_array
print("Updated HMM Array:", updated_hmm_array)

formatted_message = "\n".join(message)
print(formatted_message)
# Out:
# Current HMM Mission Time: 37
# Mission Time Deviation: [11]
# Updated Mission Time: 48
#  HMM Array: [0, 4, 3, 10.0, 37]
#  RMM Array: [0, 5, 3, 5.65, 48]
# Updated HMM Array: [[0, 5, 3, None, 48]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 10.0 seconds
# - Actual Time of Completion: 5.65 seconds
# - Expected Coordinates: (4, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 4.35 seconds.
# It is now located at position (5, 3). It has moved 1 units to the right and 0 units downward from the expected position ((4, 3)).
#
# --------------------------------------------------
# <string>:1: RuntimeWarning: coroutine 'websocket_client' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
import numpy as np

# Function to generate RMM array for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

# Sample data from server
data = ['1', '4', '3', '10.0', '48']

# Extract data from the input list
first_state = int(data[1])  # 4
second_state = int(data[2])  # 3
time_elapsed = float(data[3])  # 10.0
steps_remaining = int(data[4])  # 48
timestep = int(data[0]) - 1  # Reduce timestep by 1

# Prepare the SHMM data tuple for a single row
shmm_row = ((first_state, second_state), time_elapsed, timestep + steps_remaining)

# Generate RMM array for the current row (with index)
rmm_array = generate_rmm_array_for_row(shmm_row, timestep)

# Convert the current processed row into HMM array format (with index)
hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]  # 37 as constant

# Print the generated RMM and HMM arrays
print(f"Generated RMM array for row: {rmm_array}")
print(f"Generated HMM array for row: {hmm_array}")
# Out:
# Generated RMM array for row: [0, 4, 3, 9.19, 48]
# Generated HMM array for row: [0, 4, 3, 10.0, 37]

# %%
# Integration completed!


import asyncio
import websockets
import numpy as np

# Global variables to store the arrays
hmm_array = None
rmm_array = None

# Adjusted RMM array generation for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

import numpy as np

# Define the uncertainty factors
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    # Calculate the L1 norm (absolute difference)
    norm = np.abs(np.array(array2) - np.array(array1))
    return norm

# Function to perform a Bayesian probabilistic update
def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value


# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template


def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        # print(delay_message)
        messages.append(delay_message)  # Append formatted delay message to messages list
        # print(messages)
    return messages





# Function to dynamically update based on deviations and given logics
def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    updated_hmm_array = []  # Initialize updated_hmm_array
    current_hmm_mission_time = hmm_arrays[0][4]  # Use the mission time from hmm_arrays

    # Print the current mission time for debugging
    # print("Current HMM Mission Time:", current_hmm_mission_time)

    # Use the updated position from rmm
    updated_pos1 = rmm_arrays[0][1]  # First position from rmm
    updated_pos2 = rmm_arrays[0][2]  # Second position from rmm

    # Calculate the mission time deviation
    mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[0][4]])
    # print("Mission Time Deviation:", mission_time_deviation)
    
    # Get the first element of the deviation for updating
    mission_time_deviation_value = mission_time_deviation[0]

    # Set a dynamic threshold for mission time
    dynamic_threshold_mission_time = 2



    hmm_pos1 = hmm_arrays[0][1]
    hmm_pos2 = hmm_arrays[0][2]
    rmm_pos1 = rmm_arrays[0][1]
    rmm_pos2 = rmm_arrays[0][2]
    hmm_time = hmm_arrays[0][3]
    rmm_time = rmm_arrays[0][3]

    message = generate_communication_message(mission_time_deviation_value, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)


    
    # Update mission time using the update logic
    updated_mission_time = update_logic_functions[0](current_hmm_mission_time, mission_time_deviation_value,
                                                       dynamic_threshold_mission_time, uncertainty_factor_time)
    # print("Updated Mission Time:", updated_mission_time)

    # Append the updated values to the updated_hmm_array
    updated_hmm_array.append([0, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

    return updated_hmm_array, message



# Define the update logics
update_logics = [bayesian_probabilistic_update_general]



# Client-side WebSocket logic
async def websocket_client():
    global hmm_array, rmm_array  # Declare global variables
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        # Receive one row of data from the server
        data_from_server = await websocket.recv()
        
        # Print the raw data received from the server
        print(f"Raw data received from server: {data_from_server}")
        
        # Parse the received data (convert string to list)
        row = eval(data_from_server)  # Convert string back to list
        
        # Extract data from the row
        first_state = int(row[1])
        second_state = int(row[2])
        time_elapsed = float(row[3])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining
        
        # Prepare the SHMM data tuple for a single row
        shmm_row = ((first_state, second_state), time_elapsed, mission_time)

        # Generate RMM array for the current row (with index)
        rmm_array = generate_rmm_array_for_row(shmm_row, timestep)
        
        # Convert the current processed row into HMM array format (with index)
        hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]  # 37 as constant
        
        # # Print the generated RMM and HMM arrays
        # print(f"Generated RMM array for row: {rmm_array}")
        # print(f"Generated HMM array for row: {hmm_array}")



        # Call the function
        updated_hmm_array, message = dynamic_deviation_threshold_multi_logic(
            [hmm_array], [rmm_array], update_logics, uncertainty_factor_pos, uncertainty_factor_time)

        print(" HMM Array:", hmm_array)
        print(" RMM Array:", rmm_array)


        # Print the updated hmm_array
        print("Updated HMM Array:", updated_hmm_array)

        formatted_message = "\n".join(message)
        print(formatted_message)


        
        # Send a confirmation message back to the server
        await websocket.send("Data received and processed")
        
        # Stop after processing the first row
        print("Processing completed. Stopping client.")





# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
#  HMM Array: [0, 4, 3, 10.0, 37]
#  RMM Array: [0, 5, 3, 9.53, 48]
# Updated HMM Array: [[0, 5, 3, None, 48]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 10.0 seconds
# - Actual Time of Completion: 9.53 seconds
# - Expected Coordinates: (4, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 0.47000000000000064 seconds.
# It is now located at position (5, 3). It has moved 1 units to the right and 0 units downward from the expected position ((4, 3)).
#
# --------------------------------------------------
# Processing completed. Stopping client.

# %%
# FINAL ALL rows, DATA PROCESSED FROM SERVER, COMMUNICATION KICKED OUT.


# Integration completed!


import asyncio
import websockets
import numpy as np

# Global variables to store the arrays
hmm_array = None
rmm_array = None

# Adjusted RMM array generation for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

import numpy as np

# Define the uncertainty factors
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    # Calculate the L1 norm (absolute difference)
    norm = np.abs(np.array(array2) - np.array(array1))
    return norm

# Function to perform a Bayesian probabilistic update
def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value


# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template


def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        # print(delay_message)
        messages.append(delay_message)  # Append formatted delay message to messages list
        # print(messages)
    return messages





# Function to dynamically update based on deviations and given logics
def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    updated_hmm_array = []  # Initialize updated_hmm_array
    current_hmm_mission_time = hmm_arrays[0][4]  # Use the mission time from hmm_arrays

    # Print the current mission time for debugging
    # print("Current HMM Mission Time:", current_hmm_mission_time)

    # Use the updated position from rmm
    updated_pos1 = rmm_arrays[0][1]  # First position from rmm
    updated_pos2 = rmm_arrays[0][2]  # Second position from rmm

    # Calculate the mission time deviation
    mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[0][4]])
    # print("Mission Time Deviation:", mission_time_deviation)
    
    # Get the first element of the deviation for updating
    mission_time_deviation_value = mission_time_deviation[0]

    # Set a dynamic threshold for mission time
    dynamic_threshold_mission_time = 10



    hmm_pos1 = hmm_arrays[0][1]
    hmm_pos2 = hmm_arrays[0][2]
    rmm_pos1 = rmm_arrays[0][1]
    rmm_pos2 = rmm_arrays[0][2]
    hmm_time = hmm_arrays[0][3]
    rmm_time = rmm_arrays[0][3]

    message = generate_communication_message(mission_time_deviation_value, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)


    
    # Update mission time using the update logic
    updated_mission_time = update_logic_functions[0](current_hmm_mission_time, mission_time_deviation_value,
                                                       dynamic_threshold_mission_time, uncertainty_factor_time)
    # print("Updated Mission Time:", updated_mission_time)

    # Append the updated values to the updated_hmm_array
    updated_hmm_array.append([0, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

    return updated_hmm_array, message



# Define the update logics
update_logics = [bayesian_probabilistic_update_general]



# Client-side WebSocket logic
async def websocket_client():
    global hmm_array, rmm_array  # Declare global variables
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        while True:  # Loop to receive multiple rows
            try:
                # Receive one row of data from the server
                data_from_server = await websocket.recv()
                
                # Print the raw data received from the server
                print(f"Raw data received from server: {data_from_server}")
                
                # Parse the received data (convert string to list)
                row = eval(data_from_server)  # Convert string back to list
                
                # Check if the row is empty or if the connection has ended
                if not row:
                    break
                
                # Extract data from the row
                first_state = int(row[1])
                second_state = int(row[2])
                time_elapsed = float(row[3])
                steps_remaining = int(row[4])
                mission_time = timestep + steps_remaining
                
                # Prepare the SHMM data tuple for a single row
                shmm_row = ((first_state, second_state), time_elapsed, mission_time)

                # Generate RMM array for the current row (with index)
                rmm_array = generate_rmm_array_for_row(shmm_row, timestep)
                
                # Convert the current processed row into HMM array format (with index)
                hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 48]  # 37 as constant
                
                # Call the function
                updated_hmm_array, message = dynamic_deviation_threshold_multi_logic(
                    [hmm_array], [rmm_array], update_logics, uncertainty_factor_pos, uncertainty_factor_time)

                print("SHMM Array:", shmm_row[2])                
                print("HMM Array:", hmm_array)
                print("RMM Array:", rmm_array)

                # Print the updated hmm_array
                print("Updated HMM Array:", updated_hmm_array)

                formatted_message = "\n".join(message)
                print(formatted_message)
                
                # Send a confirmation message back to the server
                await websocket.send("Data received and processed")
                
                timestep += 1  # Increment timestep for each row

            except websockets.exceptions.ConnectionClosed:
                print("Connection closed")
                break
        
        print("Processing completed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# SHMM Array: 48
# HMM Array: [0, 4, 3, 10.0, 48]
# RMM Array: [0, 5, 3, 8.63, 48]
# Updated HMM Array: [[0, 5, 3, None, 48]]
#
# Raw data received from server: ['2', '4', '2', '20.0', '47']
# SHMM Array: 48
# HMM Array: [1, 4, 2, 20.0, 48]
# RMM Array: [1, 3, 2, 17.7, 48]
# Updated HMM Array: [[0, 3, 2, None, 48]]
#
# Raw data received from server: ['3', '4', '1', '30.0', '46']
# SHMM Array: 48
# HMM Array: [2, 4, 1, 30.0, 48]
# RMM Array: [2, 4, 1, 26.69, 48]
# Updated HMM Array: [[0, 4, 1, None, 48]]
#
# Raw data received from server: ['4', '3', '1', '40.0', '49']
# SHMM Array: 52
# HMM Array: [3, 3, 1, 40.0, 48]
# RMM Array: [3, 3, 1, 37.57, 52]
# Updated HMM Array: [[0, 3, 1, None, 52]]
#
# Raw data received from server: ['5', '2', '1', '50.0', '52']
# SHMM Array: 56
# HMM Array: [4, 2, 1, 50.0, 48]
# RMM Array: [4, 1, 1, 51.74, 56]
# Updated HMM Array: [[0, 1, 1, None, 56]]
#
# Raw data received from server: ['6', '1', '1', '60.0', '55']
# SHMM Array: 60
# HMM Array: [5, 1, 1, 60.0, 48]
# RMM Array: [5, 0, 1, 58.49, 60]
# Updated HMM Array: [[0, 0, 1, None, 72]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 60.0 seconds
# - Actual Time of Completion: 58.49 seconds
# - Expected Coordinates: (1, 1)
# - Actual Coordinates: (0, 1)
#
# The robot is ahead of schedule by 1.509999999999998 seconds.
# It is now located at position (0, 1). It has moved 1 units to the left and 0 units downward from the expected position ((1, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['7', '1', '0', '110.0', '56']
# SHMM Array: 62
# HMM Array: [6, 1, 0, 110.0, 48]
# RMM Array: [6, 3, 0, 111.99, 62]
# Updated HMM Array: [[0, 3, 0, None, 76]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 110.0 seconds
# - Actual Time of Completion: 111.99 seconds
# - Expected Coordinates: (1, 0)
# - Actual Coordinates: (3, 0)
#
# The robot is currently experiencing a delay of 1.9899999999999949 seconds.
# It is now located at position (3, 0). It has moved 2 units to the right and 0 units downward from the expected position ((1, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['8', '2', '0', '120.0', '55']
# SHMM Array: 62
# HMM Array: [7, 2, 0, 120.0, 48]
# RMM Array: [7, 3, 0, 118.92, 62]
# Updated HMM Array: [[0, 3, 0, None, 76]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 120.0 seconds
# - Actual Time of Completion: 118.92 seconds
# - Expected Coordinates: (2, 0)
# - Actual Coordinates: (3, 0)
#
# The robot is ahead of schedule by 1.0799999999999983 seconds.
# It is now located at position (3, 0). It has moved 1 units to the right and 0 units downward from the expected position ((2, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['9', '3', '0', '130.0', '54']
# SHMM Array: 62
# HMM Array: [8, 3, 0, 130.0, 48]
# RMM Array: [8, 3, 0, 128.41, 62]
# Updated HMM Array: [[0, 3, 0, None, 76]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 130.0 seconds
# - Actual Time of Completion: 128.41 seconds
# - Expected Coordinates: (3, 0)
# - Actual Coordinates: (3, 0)
#
# The robot is ahead of schedule by 1.5900000000000034 seconds.
# It is now located at position (3, 0).
#
# --------------------------------------------------
# Raw data received from server: ['10', '4', '0', '140.0', '53']
# SHMM Array: 62
# HMM Array: [9, 4, 0, 140.0, 48]
# RMM Array: [9, 3, 0, 137.24, 62]
# Updated HMM Array: [[0, 3, 0, None, 76]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 140.0 seconds
# - Actual Time of Completion: 137.24 seconds
# - Expected Coordinates: (4, 0)
# - Actual Coordinates: (3, 0)
#
# The robot is ahead of schedule by 2.759999999999991 seconds.
# It is now located at position (3, 0). It has moved 1 units to the left and 0 units downward from the expected position ((4, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['11', '5', '0', '150.0', '52']
# SHMM Array: 62
# HMM Array: [10, 5, 0, 150.0, 48]
# RMM Array: [10, 5, 0, 145.38, 62]
# Updated HMM Array: [[0, 5, 0, None, 76]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 150.0 seconds
# - Actual Time of Completion: 145.38 seconds
# - Expected Coordinates: (5, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is ahead of schedule by 4.6200000000000045 seconds.
# It is now located at position (5, 0).
#
# --------------------------------------------------
# Raw data received from server: ['12', '6', '0', '160.0', '55']
# SHMM Array: 66
# HMM Array: [11, 6, 0, 160.0, 48]
# RMM Array: [11, 5, 0, 158.66, 66]
# Updated HMM Array: [[0, 5, 0, None, 84]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 160.0 seconds
# - Actual Time of Completion: 158.66 seconds
# - Expected Coordinates: (6, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is ahead of schedule by 1.3400000000000034 seconds.
# It is now located at position (5, 0). It has moved 1 units to the left and 0 units downward from the expected position ((6, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['13', '7', '0', '170.0', '58']
# SHMM Array: 70
# HMM Array: [12, 7, 0, 170.0, 48]
# RMM Array: [12, 5, 0, 165.49, 70]
# Updated HMM Array: [[0, 5, 0, None, 92]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 170.0 seconds
# - Actual Time of Completion: 165.49 seconds
# - Expected Coordinates: (7, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is ahead of schedule by 4.509999999999991 seconds.
# It is now located at position (5, 0). It has moved 2 units to the left and 0 units downward from the expected position ((7, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['14', '8', '0', '180.0', '61']
# SHMM Array: 74
# HMM Array: [13, 8, 0, 180.0, 48]
# RMM Array: [13, 5, 0, 178.95, 74]
# Updated HMM Array: [[0, 5, 0, None, 100]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 180.0 seconds
# - Actual Time of Completion: 178.95 seconds
# - Expected Coordinates: (8, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is ahead of schedule by 1.0500000000000114 seconds.
# It is now located at position (5, 0). It has moved 3 units to the left and 0 units downward from the expected position ((8, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['15', '9', '0', '190.0', '64']
# SHMM Array: 78
# HMM Array: [14, 9, 0, 190.0, 48]
# RMM Array: [14, 5, 0, 196.18, 78]
# Updated HMM Array: [[0, 5, 0, None, 108]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 190.0 seconds
# - Actual Time of Completion: 196.18 seconds
# - Expected Coordinates: (9, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is currently experiencing a delay of 6.180000000000007 seconds.
# It is now located at position (5, 0). It has moved 4 units to the left and 0 units downward from the expected position ((9, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['16', '9', '1', '200.0', '63']
# SHMM Array: 78
# HMM Array: [15, 9, 1, 200.0, 48]
# RMM Array: [15, 5, 1, 199.6, 78]
# Updated HMM Array: [[0, 5, 1, None, 108]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 200.0 seconds
# - Actual Time of Completion: 199.6 seconds
# - Expected Coordinates: (9, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 0.4000000000000057 seconds.
# It is now located at position (5, 1). It has moved 4 units to the left and 0 units downward from the expected position ((9, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['17', '9', '2', '210.0', '62']
# SHMM Array: 78
# HMM Array: [16, 9, 2, 210.0, 48]
# RMM Array: [16, 5, 2, 211.8, 78]
# Updated HMM Array: [[0, 5, 2, None, 108]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 210.0 seconds
# - Actual Time of Completion: 211.8 seconds
# - Expected Coordinates: (9, 2)
# - Actual Coordinates: (5, 2)
#
# The robot is currently experiencing a delay of 1.8000000000000114 seconds.
# It is now located at position (5, 2). It has moved 4 units to the left and 0 units downward from the expected position ((9, 2)).
#
# --------------------------------------------------
# Raw data received from server: ['18', '9', '3', '220.0', '61']
# SHMM Array: 78
# HMM Array: [17, 9, 3, 220.0, 48]
# RMM Array: [17, 5, 3, 220.54, 78]
# Updated HMM Array: [[0, 5, 3, None, 108]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 220.0 seconds
# - Actual Time of Completion: 220.54 seconds
# - Expected Coordinates: (9, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.539999999999992 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 0 units downward from the expected position ((9, 3)).
#
# --------------------------------------------------
# Raw data received from server: ['19', '9', '4', '230.0', '60']
# SHMM Array: 78
# HMM Array: [18, 9, 4, 230.0, 48]
# RMM Array: [18, 5, 3, 227.48, 78]
# Updated HMM Array: [[0, 5, 3, None, 108]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 230.0 seconds
# - Actual Time of Completion: 227.48 seconds
# - Expected Coordinates: (9, 4)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 2.5200000000000102 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 1 units downward from the expected position ((9, 4)).
#
# --------------------------------------------------
# Raw data received from server: ['20', '9', '3', '240.0', '69']
# SHMM Array: 88
# HMM Array: [19, 9, 3, 240.0, 48]
# RMM Array: [19, 5, 3, 243.91, 88]
# Updated HMM Array: [[0, 5, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 240.0 seconds
# - Actual Time of Completion: 243.91 seconds
# - Expected Coordinates: (9, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 3.9099999999999966 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 0 units downward from the expected position ((9, 3)).
#
# --------------------------------------------------
# Raw data received from server: ['21', '9', '2', '250.0', '68']
# SHMM Array: 88
# HMM Array: [20, 9, 2, 250.0, 48]
# RMM Array: [20, 5, 2, 251.43, 88]
# Updated HMM Array: [[0, 5, 2, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 250.0 seconds
# - Actual Time of Completion: 251.43 seconds
# - Expected Coordinates: (9, 2)
# - Actual Coordinates: (5, 2)
#
# The robot is currently experiencing a delay of 1.4300000000000068 seconds.
# It is now located at position (5, 2). It has moved 4 units to the left and 0 units downward from the expected position ((9, 2)).
#
# --------------------------------------------------
# Raw data received from server: ['22', '9', '1', '260.0', '67']
# SHMM Array: 88
# HMM Array: [21, 9, 1, 260.0, 48]
# RMM Array: [21, 5, 1, 256.58, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 260.0 seconds
# - Actual Time of Completion: 256.58 seconds
# - Expected Coordinates: (9, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 3.420000000000016 seconds.
# It is now located at position (5, 1). It has moved 4 units to the left and 0 units downward from the expected position ((9, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['23', '8', '1', '310.0', '66']
# SHMM Array: 88
# HMM Array: [22, 8, 1, 310.0, 48]
# RMM Array: [22, 5, 1, 313.1, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 310.0 seconds
# - Actual Time of Completion: 313.1 seconds
# - Expected Coordinates: (8, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is currently experiencing a delay of 3.1000000000000227 seconds.
# It is now located at position (5, 1). It has moved 3 units to the left and 0 units downward from the expected position ((8, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['24', '7', '1', '320.0', '65']
# SHMM Array: 88
# HMM Array: [23, 7, 1, 320.0, 48]
# RMM Array: [23, 5, 1, 321.14, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 320.0 seconds
# - Actual Time of Completion: 321.14 seconds
# - Expected Coordinates: (7, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is currently experiencing a delay of 1.1399999999999864 seconds.
# It is now located at position (5, 1). It has moved 2 units to the left and 0 units downward from the expected position ((7, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['25', '6', '1', '330.0', '64']
# SHMM Array: 88
# HMM Array: [24, 6, 1, 330.0, 48]
# RMM Array: [24, 5, 1, 329.43, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 330.0 seconds
# - Actual Time of Completion: 329.43 seconds
# - Expected Coordinates: (6, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 0.5699999999999932 seconds.
# It is now located at position (5, 1). It has moved 1 units to the left and 0 units downward from the expected position ((6, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['26', '5', '1', '340.0', '63']
# SHMM Array: 88
# HMM Array: [25, 5, 1, 340.0, 48]
# RMM Array: [25, 4, 1, 340.05, 88]
# Updated HMM Array: [[0, 4, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 340.0 seconds
# - Actual Time of Completion: 340.05 seconds
# - Expected Coordinates: (5, 1)
# - Actual Coordinates: (4, 1)
#
# The robot is currently experiencing a delay of 0.05000000000001137 seconds.
# It is now located at position (4, 1). It has moved 1 units to the left and 0 units downward from the expected position ((5, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['27', '5', '2', '350.0', '62']
# SHMM Array: 88
# HMM Array: [26, 5, 2, 350.0, 48]
# RMM Array: [26, 4, 2, 353.07, 88]
# Updated HMM Array: [[0, 4, 2, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 350.0 seconds
# - Actual Time of Completion: 353.07 seconds
# - Expected Coordinates: (5, 2)
# - Actual Coordinates: (4, 2)
#
# The robot is currently experiencing a delay of 3.069999999999993 seconds.
# It is now located at position (4, 2). It has moved 1 units to the left and 0 units downward from the expected position ((5, 2)).
#
# --------------------------------------------------
# Raw data received from server: ['28', '5', '3', '360.0', '61']
# SHMM Array: 88
# HMM Array: [27, 5, 3, 360.0, 48]
# RMM Array: [27, 5, 3, 360.7, 88]
# Updated HMM Array: [[0, 5, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 360.0 seconds
# - Actual Time of Completion: 360.7 seconds
# - Expected Coordinates: (5, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.6999999999999886 seconds.
# It is now located at position (5, 3).
#
# --------------------------------------------------
# Raw data received from server: ['29', '5', '4', '370.0', '60']
# SHMM Array: 88
# HMM Array: [28, 5, 4, 370.0, 48]
# RMM Array: [28, 3, 3, 370.73, 88]
# Updated HMM Array: [[0, 3, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 370.0 seconds
# - Actual Time of Completion: 370.73 seconds
# - Expected Coordinates: (5, 4)
# - Actual Coordinates: (3, 3)
#
# The robot is currently experiencing a delay of 0.7300000000000182 seconds.
# It is now located at position (3, 3). It has moved 2 units to the left and 1 units downward from the expected position ((5, 4)).
#
# --------------------------------------------------
# Raw data received from server: ['30', '5', '3', '380.0', '59']
# SHMM Array: 88
# HMM Array: [29, 5, 3, 380.0, 48]
# RMM Array: [29, 5, 3, 384.39, 88]
# Updated HMM Array: [[0, 5, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 380.0 seconds
# - Actual Time of Completion: 384.39 seconds
# - Expected Coordinates: (5, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 4.389999999999986 seconds.
# It is now located at position (5, 3).
#
# --------------------------------------------------
# Raw data received from server: ['31', '5', '2', '390.0', '58']
# SHMM Array: 88
# HMM Array: [30, 5, 2, 390.0, 48]
# RMM Array: [30, 5, 2, 389.54, 88]
# Updated HMM Array: [[0, 5, 2, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 390.0 seconds
# - Actual Time of Completion: 389.54 seconds
# - Expected Coordinates: (5, 2)
# - Actual Coordinates: (5, 2)
#
# The robot is ahead of schedule by 0.45999999999997954 seconds.
# It is now located at position (5, 2).
#
# --------------------------------------------------
# Raw data received from server: ['32', '5', '1', '400.0', '57']
# SHMM Array: 88
# HMM Array: [31, 5, 1, 400.0, 48]
# RMM Array: [31, 3, 1, 397.55, 88]
# Updated HMM Array: [[0, 3, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 400.0 seconds
# - Actual Time of Completion: 397.55 seconds
# - Expected Coordinates: (5, 1)
# - Actual Coordinates: (3, 1)
#
# The robot is ahead of schedule by 2.4499999999999886 seconds.
# It is now located at position (3, 1). It has moved 2 units to the left and 0 units downward from the expected position ((5, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['33', '6', '1', '410.0', '56']
# SHMM Array: 88
# HMM Array: [32, 6, 1, 410.0, 48]
# RMM Array: [32, 4, 1, 411.17, 88]
# Updated HMM Array: [[0, 4, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 410.0 seconds
# - Actual Time of Completion: 411.17 seconds
# - Expected Coordinates: (6, 1)
# - Actual Coordinates: (4, 1)
#
# The robot is currently experiencing a delay of 1.170000000000016 seconds.
# It is now located at position (4, 1). It has moved 2 units to the left and 0 units downward from the expected position ((6, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['34', '7', '1', '420.0', '55']
# SHMM Array: 88
# HMM Array: [33, 7, 1, 420.0, 48]
# RMM Array: [33, 5, 1, 418.41, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 420.0 seconds
# - Actual Time of Completion: 418.41 seconds
# - Expected Coordinates: (7, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 1.589999999999975 seconds.
# It is now located at position (5, 1). It has moved 2 units to the left and 0 units downward from the expected position ((7, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['35', '8', '1', '430.0', '54']
# SHMM Array: 88
# HMM Array: [34, 8, 1, 430.0, 48]
# RMM Array: [34, 5, 1, 429.72, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 430.0 seconds
# - Actual Time of Completion: 429.72 seconds
# - Expected Coordinates: (8, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 0.2799999999999727 seconds.
# It is now located at position (5, 1). It has moved 3 units to the left and 0 units downward from the expected position ((8, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['36', '9', '1', '440.0', '53']
# SHMM Array: 88
# HMM Array: [35, 9, 1, 440.0, 48]
# RMM Array: [35, 5, 1, 442.35, 88]
# Updated HMM Array: [[0, 5, 1, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 440.0 seconds
# - Actual Time of Completion: 442.35 seconds
# - Expected Coordinates: (9, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is currently experiencing a delay of 2.3500000000000227 seconds.
# It is now located at position (5, 1). It has moved 4 units to the left and 0 units downward from the expected position ((9, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['37', '9', '2', '450.0', '52']
# SHMM Array: 88
# HMM Array: [36, 9, 2, 450.0, 48]
# RMM Array: [36, 5, 2, 453.13, 88]
# Updated HMM Array: [[0, 5, 2, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 450.0 seconds
# - Actual Time of Completion: 453.13 seconds
# - Expected Coordinates: (9, 2)
# - Actual Coordinates: (5, 2)
#
# The robot is currently experiencing a delay of 3.1299999999999955 seconds.
# It is now located at position (5, 2). It has moved 4 units to the left and 0 units downward from the expected position ((9, 2)).
#
# --------------------------------------------------
# Raw data received from server: ['38', '9', '3', '460.0', '51']
# SHMM Array: 88
# HMM Array: [37, 9, 3, 460.0, 48]
# RMM Array: [37, 5, 3, 463.41, 88]
# Updated HMM Array: [[0, 5, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 460.0 seconds
# - Actual Time of Completion: 463.41 seconds
# - Expected Coordinates: (9, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 3.410000000000025 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 0 units downward from the expected position ((9, 3)).
#
# --------------------------------------------------
# Raw data received from server: ['39', '9', '4', '470.0', '50']
# SHMM Array: 88
# HMM Array: [38, 9, 4, 470.0, 48]
# RMM Array: [38, 5, 3, 471.81, 88]
# Updated HMM Array: [[0, 5, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 470.0 seconds
# - Actual Time of Completion: 471.81 seconds
# - Expected Coordinates: (9, 4)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 1.8100000000000023 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 1 units downward from the expected position ((9, 4)).
#
# --------------------------------------------------
# Raw data received from server: ['40', '9', '5', '480.0', '49']
# SHMM Array: 88
# HMM Array: [39, 9, 5, 480.0, 48]
# RMM Array: [39, 5, 3, 483.42, 88]
# Updated HMM Array: [[0, 5, 3, None, 128]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 480.0 seconds
# - Actual Time of Completion: 483.42 seconds
# - Expected Coordinates: (9, 5)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 3.420000000000016 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 2 units downward from the expected position ((9, 5)).
#
# --------------------------------------------------
# Raw data received from server: ['41', '9', '6', '500.0', '67']
# SHMM Array: 107
# HMM Array: [40, 9, 6, 500.0, 48]
# RMM Array: [40, 5, 3, 495.7, 107]
# Updated HMM Array: [[0, 5, 3, None, 166]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 500.0 seconds
# - Actual Time of Completion: 495.7 seconds
# - Expected Coordinates: (9, 6)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 4.300000000000011 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 3 units downward from the expected position ((9, 6)).
#
# --------------------------------------------------
# Raw data received from server: ['42', '9', '7', '510.0', '70']
# SHMM Array: 111
# HMM Array: [41, 9, 7, 510.0, 48]
# RMM Array: [41, 5, 3, 510.39, 111]
# Updated HMM Array: [[0, 5, 3, None, 174]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 510.0 seconds
# - Actual Time of Completion: 510.39 seconds
# - Expected Coordinates: (9, 7)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.38999999999998636 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 4 units downward from the expected position ((9, 7)).
#
# --------------------------------------------------
# Raw data received from server: ['43', '9', '8', '520.0', '73']
# SHMM Array: 115
# HMM Array: [42, 9, 8, 520.0, 48]
# RMM Array: [42, 5, 3, 518.76, 115]
# Updated HMM Array: [[0, 5, 3, None, 182]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 520.0 seconds
# - Actual Time of Completion: 518.76 seconds
# - Expected Coordinates: (9, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 1.240000000000009 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 5 units downward from the expected position ((9, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['44', '9', '9', '530.0', '76']
# SHMM Array: 119
# HMM Array: [43, 9, 9, 530.0, 48]
# RMM Array: [43, 5, 3, 530.95, 119]
# Updated HMM Array: [[0, 5, 3, None, 190]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 530.0 seconds
# - Actual Time of Completion: 530.95 seconds
# - Expected Coordinates: (9, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.9500000000000455 seconds.
# It is now located at position (5, 3). It has moved 4 units to the left and 6 units downward from the expected position ((9, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['45', '8', '9', '540.0', '75']
# SHMM Array: 119
# HMM Array: [44, 8, 9, 540.0, 48]
# RMM Array: [44, 5, 3, 540.34, 119]
# Updated HMM Array: [[0, 5, 3, None, 190]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 540.0 seconds
# - Actual Time of Completion: 540.34 seconds
# - Expected Coordinates: (8, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.34000000000003183 seconds.
# It is now located at position (5, 3). It has moved 3 units to the left and 6 units downward from the expected position ((8, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['46', '7', '9', '550.0', '74']
# SHMM Array: 119
# HMM Array: [45, 7, 9, 550.0, 48]
# RMM Array: [45, 5, 3, 549.37, 119]
# Updated HMM Array: [[0, 5, 3, None, 190]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 550.0 seconds
# - Actual Time of Completion: 549.37 seconds
# - Expected Coordinates: (7, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 0.6299999999999955 seconds.
# It is now located at position (5, 3). It has moved 2 units to the left and 6 units downward from the expected position ((7, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['47', '6', '9', '560.0', '73']
# SHMM Array: 119
# HMM Array: [46, 6, 9, 560.0, 48]
# RMM Array: [46, 5, 3, 560.27, 119]
# Updated HMM Array: [[0, 5, 3, None, 190]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 560.0 seconds
# - Actual Time of Completion: 560.27 seconds
# - Expected Coordinates: (6, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.2699999999999818 seconds.
# It is now located at position (5, 3). It has moved 1 units to the left and 6 units downward from the expected position ((6, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['48', '5', '9', '570.0', '72']
# SHMM Array: 119
# HMM Array: [47, 5, 9, 570.0, 48]
# RMM Array: [47, 4, 3, 570.1, 119]
# Updated HMM Array: [[0, 4, 3, None, 190]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 570.0 seconds
# - Actual Time of Completion: 570.1 seconds
# - Expected Coordinates: (5, 9)
# - Actual Coordinates: (4, 3)
#
# The robot is currently experiencing a delay of 0.10000000000002274 seconds.
# It is now located at position (4, 3). It has moved 1 units to the left and 6 units downward from the expected position ((5, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['49', '6', '9', '580.0', '75']
# SHMM Array: 123
# HMM Array: [48, 6, 9, 580.0, 48]
# RMM Array: [48, 5, 3, 583.56, 123]
# Updated HMM Array: [[0, 5, 3, None, 198]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 580.0 seconds
# - Actual Time of Completion: 583.56 seconds
# - Expected Coordinates: (6, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 3.5599999999999454 seconds.
# It is now located at position (5, 3). It has moved 1 units to the left and 6 units downward from the expected position ((6, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['50', '7', '9', '590.0', '78']
# SHMM Array: 127
# HMM Array: [49, 7, 9, 590.0, 48]
# RMM Array: [49, 5, 3, 591.0, 127]
# Updated HMM Array: [[0, 5, 3, None, 206]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 590.0 seconds
# - Actual Time of Completion: 591.0 seconds
# - Expected Coordinates: (7, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 1.0 seconds.
# It is now located at position (5, 3). It has moved 2 units to the left and 6 units downward from the expected position ((7, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['51', '8', '9', '600.0', '81']
# SHMM Array: 131
# HMM Array: [50, 8, 9, 600.0, 48]
# RMM Array: [50, 5, 3, 597.51, 131]
# Updated HMM Array: [[0, 5, 3, None, 214]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 600.0 seconds
# - Actual Time of Completion: 597.51 seconds
# - Expected Coordinates: (8, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 2.490000000000009 seconds.
# It is now located at position (5, 3). It has moved 3 units to the left and 6 units downward from the expected position ((8, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['52', '8', '8', '650.0', '78']
# SHMM Array: 129
# HMM Array: [51, 8, 8, 650.0, 48]
# RMM Array: [51, 5, 3, 652.85, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 650.0 seconds
# - Actual Time of Completion: 652.85 seconds
# - Expected Coordinates: (8, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 2.8500000000000227 seconds.
# It is now located at position (5, 3). It has moved 3 units to the left and 5 units downward from the expected position ((8, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['53', '7', '8', '660.0', '77']
# SHMM Array: 129
# HMM Array: [52, 7, 8, 660.0, 48]
# RMM Array: [52, 5, 3, 659.26, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 660.0 seconds
# - Actual Time of Completion: 659.26 seconds
# - Expected Coordinates: (7, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 0.7400000000000091 seconds.
# It is now located at position (5, 3). It has moved 2 units to the left and 5 units downward from the expected position ((7, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['54', '6', '8', '670.0', '76']
# SHMM Array: 129
# HMM Array: [53, 6, 8, 670.0, 48]
# RMM Array: [53, 5, 3, 673.96, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 670.0 seconds
# - Actual Time of Completion: 673.96 seconds
# - Expected Coordinates: (6, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 3.9600000000000364 seconds.
# It is now located at position (5, 3). It has moved 1 units to the left and 5 units downward from the expected position ((6, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['55', '5', '8', '680.0', '75']
# SHMM Array: 129
# HMM Array: [54, 5, 8, 680.0, 48]
# RMM Array: [54, 5, 3, 681.11, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 680.0 seconds
# - Actual Time of Completion: 681.11 seconds
# - Expected Coordinates: (5, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 1.1100000000000136 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 5 units downward from the expected position ((5, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['56', '5', '7', '690.0', '74']
# SHMM Array: 129
# HMM Array: [55, 5, 7, 690.0, 48]
# RMM Array: [55, 5, 3, 690.73, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 690.0 seconds
# - Actual Time of Completion: 690.73 seconds
# - Expected Coordinates: (5, 7)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.7300000000000182 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 4 units downward from the expected position ((5, 7)).
#
# --------------------------------------------------
# Raw data received from server: ['57', '5', '6', '700.0', '73']
# SHMM Array: 129
# HMM Array: [56, 5, 6, 700.0, 48]
# RMM Array: [56, 5, 3, 698.17, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 700.0 seconds
# - Actual Time of Completion: 698.17 seconds
# - Expected Coordinates: (5, 6)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 1.830000000000041 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 3 units downward from the expected position ((5, 6)).
#
# --------------------------------------------------
# Raw data received from server: ['58', '5', '5', '710.0', '72']
# SHMM Array: 129
# HMM Array: [57, 5, 5, 710.0, 48]
# RMM Array: [57, 5, 3, 708.33, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 710.0 seconds
# - Actual Time of Completion: 708.33 seconds
# - Expected Coordinates: (5, 5)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 1.669999999999959 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 2 units downward from the expected position ((5, 5)).
#
# --------------------------------------------------
# Raw data received from server: ['59', '5', '6', '720.0', '71']
# SHMM Array: 129
# HMM Array: [58, 5, 6, 720.0, 48]
# RMM Array: [58, 3, 3, 721.66, 129]
# Updated HMM Array: [[0, 3, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 720.0 seconds
# - Actual Time of Completion: 721.66 seconds
# - Expected Coordinates: (5, 6)
# - Actual Coordinates: (3, 3)
#
# The robot is currently experiencing a delay of 1.6599999999999682 seconds.
# It is now located at position (3, 3). It has moved 2 units to the left and 3 units downward from the expected position ((5, 6)).
#
# --------------------------------------------------
# Raw data received from server: ['60', '5', '7', '730.0', '70']
# SHMM Array: 129
# HMM Array: [59, 5, 7, 730.0, 48]
# RMM Array: [59, 4, 3, 725.8, 129]
# Updated HMM Array: [[0, 4, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 730.0 seconds
# - Actual Time of Completion: 725.8 seconds
# - Expected Coordinates: (5, 7)
# - Actual Coordinates: (4, 3)
#
# The robot is ahead of schedule by 4.2000000000000455 seconds.
# It is now located at position (4, 3). It has moved 1 units to the left and 4 units downward from the expected position ((5, 7)).
#
# --------------------------------------------------
# Raw data received from server: ['61', '5', '8', '740.0', '69']
# SHMM Array: 129
# HMM Array: [60, 5, 8, 740.0, 48]
# RMM Array: [60, 5, 3, 741.23, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 740.0 seconds
# - Actual Time of Completion: 741.23 seconds
# - Expected Coordinates: (5, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 1.2300000000000182 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 5 units downward from the expected position ((5, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['62', '6', '8', '750.0', '68']
# SHMM Array: 129
# HMM Array: [61, 6, 8, 750.0, 48]
# RMM Array: [61, 5, 3, 752.37, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 750.0 seconds
# - Actual Time of Completion: 752.37 seconds
# - Expected Coordinates: (6, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 2.3700000000000045 seconds.
# It is now located at position (5, 3). It has moved 1 units to the left and 5 units downward from the expected position ((6, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['63', '7', '8', '760.0', '67']
# SHMM Array: 129
# HMM Array: [62, 7, 8, 760.0, 48]
# RMM Array: [62, 5, 3, 759.61, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 760.0 seconds
# - Actual Time of Completion: 759.61 seconds
# - Expected Coordinates: (7, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 0.38999999999998636 seconds.
# It is now located at position (5, 3). It has moved 2 units to the left and 5 units downward from the expected position ((7, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['64', '8', '8', '770.0', '66']
# SHMM Array: 129
# HMM Array: [63, 8, 8, 770.0, 48]
# RMM Array: [63, 5, 3, 768.01, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 770.0 seconds
# - Actual Time of Completion: 768.01 seconds
# - Expected Coordinates: (8, 8)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 1.990000000000009 seconds.
# It is now located at position (5, 3). It has moved 3 units to the left and 5 units downward from the expected position ((8, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['65', '8', '9', '780.0', '65']
# SHMM Array: 129
# HMM Array: [64, 8, 9, 780.0, 48]
# RMM Array: [64, 5, 3, 781.45, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 780.0 seconds
# - Actual Time of Completion: 781.45 seconds
# - Expected Coordinates: (8, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 1.4500000000000455 seconds.
# It is now located at position (5, 3). It has moved 3 units to the left and 6 units downward from the expected position ((8, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['66', '7', '9', '790.0', '64']
# SHMM Array: 129
# HMM Array: [65, 7, 9, 790.0, 48]
# RMM Array: [65, 5, 3, 788.84, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 790.0 seconds
# - Actual Time of Completion: 788.84 seconds
# - Expected Coordinates: (7, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 1.1599999999999682 seconds.
# It is now located at position (5, 3). It has moved 2 units to the left and 6 units downward from the expected position ((7, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['67', '6', '9', '800.0', '63']
# SHMM Array: 129
# HMM Array: [66, 6, 9, 800.0, 48]
# RMM Array: [66, 5, 3, 796.8, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 800.0 seconds
# - Actual Time of Completion: 796.8 seconds
# - Expected Coordinates: (6, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is ahead of schedule by 3.2000000000000455 seconds.
# It is now located at position (5, 3). It has moved 1 units to the left and 6 units downward from the expected position ((6, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['68', '5', '9', '810.0', '62']
# SHMM Array: 129
# HMM Array: [67, 5, 9, 810.0, 48]
# RMM Array: [67, 5, 3, 810.36, 129]
# Updated HMM Array: [[0, 5, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 810.0 seconds
# - Actual Time of Completion: 810.36 seconds
# - Expected Coordinates: (5, 9)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 0.36000000000001364 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 6 units downward from the expected position ((5, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['69', '4', '9', '820.0', '61']
# SHMM Array: 129
# HMM Array: [68, 4, 9, 820.0, 48]
# RMM Array: [68, 3, 3, 818.91, 129]
# Updated HMM Array: [[0, 3, 3, None, 210]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 820.0 seconds
# - Actual Time of Completion: 818.91 seconds
# - Expected Coordinates: (4, 9)
# - Actual Coordinates: (3, 3)
#
# The robot is ahead of schedule by 1.0900000000000318 seconds.
# It is now located at position (3, 3). It has moved 1 units to the left and 6 units downward from the expected position ((4, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['70', '3', '9', '840.0', '79']
# SHMM Array: 148
# HMM Array: [69, 3, 9, 840.0, 48]
# RMM Array: [69, 2, 3, 842.34, 148]
# Updated HMM Array: [[0, 2, 3, None, 248]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 840.0 seconds
# - Actual Time of Completion: 842.34 seconds
# - Expected Coordinates: (3, 9)
# - Actual Coordinates: (2, 3)
#
# The robot is currently experiencing a delay of 2.340000000000032 seconds.
# It is now located at position (2, 3). It has moved 1 units to the left and 6 units downward from the expected position ((3, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['71', '2', '9', '850.0', '82']
# SHMM Array: 152
# HMM Array: [70, 2, 9, 850.0, 48]
# RMM Array: [70, 3, 3, 849.54, 152]
# Updated HMM Array: [[0, 3, 3, None, 256]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 850.0 seconds
# - Actual Time of Completion: 849.54 seconds
# - Expected Coordinates: (2, 9)
# - Actual Coordinates: (3, 3)
#
# The robot is ahead of schedule by 0.4600000000000364 seconds.
# It is now located at position (3, 3). It has moved 1 units to the right and 6 units downward from the expected position ((2, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['72', '1', '9', '860.0', '85']
# SHMM Array: 156
# HMM Array: [71, 1, 9, 860.0, 48]
# RMM Array: [71, 2, 3, 860.68, 156]
# Updated HMM Array: [[0, 2, 3, None, 264]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 860.0 seconds
# - Actual Time of Completion: 860.68 seconds
# - Expected Coordinates: (1, 9)
# - Actual Coordinates: (2, 3)
#
# The robot is currently experiencing a delay of 0.67999999999995 seconds.
# It is now located at position (2, 3). It has moved 1 units to the right and 6 units downward from the expected position ((1, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['73', '0', '9', '870.0', '88']
# SHMM Array: 160
# HMM Array: [72, 0, 9, 870.0, 48]
# RMM Array: [72, 2, 3, 872.06, 160]
# Updated HMM Array: [[0, 2, 3, None, 272]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 870.0 seconds
# - Actual Time of Completion: 872.06 seconds
# - Expected Coordinates: (0, 9)
# - Actual Coordinates: (2, 3)
#
# The robot is currently experiencing a delay of 2.0599999999999454 seconds.
# It is now located at position (2, 3). It has moved 2 units to the right and 6 units downward from the expected position ((0, 9)).
#
# --------------------------------------------------
# Raw data received from server: ['74', '0', '8', '880.0', '87']
# SHMM Array: 160
# HMM Array: [73, 0, 8, 880.0, 48]
# RMM Array: [73, 1, 3, 879.37, 160]
# Updated HMM Array: [[0, 1, 3, None, 272]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 880.0 seconds
# - Actual Time of Completion: 879.37 seconds
# - Expected Coordinates: (0, 8)
# - Actual Coordinates: (1, 3)
#
# The robot is ahead of schedule by 0.6299999999999955 seconds.
# It is now located at position (1, 3). It has moved 1 units to the right and 5 units downward from the expected position ((0, 8)).
#
# --------------------------------------------------
# Raw data received from server: ['75', '0', '7', '890.0', '86']
# SHMM Array: 160
# HMM Array: [74, 0, 7, 890.0, 48]
# RMM Array: [74, 1, 3, 894.65, 160]
# Updated HMM Array: [[0, 1, 3, None, 272]]
# --------------------------------------------------
# Commander,
#
# ...
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2250.0 seconds
# - Actual Time of Completion: 2250.72 seconds
# - Expected Coordinates: (2, 4)
# - Actual Coordinates: (3, 3)
#
# The robot is currently experiencing a delay of 0.7199999999997999 seconds.
# It is now located at position (3, 3). It has moved 1 units to the right and 1 units downward from the expected position ((2, 4)).
#
# --------------------------------------------------
# Raw data received from server: ['195', '1', '4', '2260.0', '22']
# SHMM Array: 216
# HMM Array: [194, 1, 4, 2260.0, 48]
# RMM Array: [194, 2, 3, 2257.95, 216]
# Updated HMM Array: [[0, 2, 3, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2260.0 seconds
# - Actual Time of Completion: 2257.95 seconds
# - Expected Coordinates: (1, 4)
# - Actual Coordinates: (2, 3)
#
# The robot is ahead of schedule by 2.050000000000182 seconds.
# It is now located at position (2, 3). It has moved 1 units to the right and 1 units downward from the expected position ((1, 4)).
#
# --------------------------------------------------
# Raw data received from server: ['196', '1', '3', '2270.0', '21']
# SHMM Array: 216
# HMM Array: [195, 1, 3, 2270.0, 48]
# RMM Array: [195, 0, 3, 2269.17, 216]
# Updated HMM Array: [[0, 0, 3, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2270.0 seconds
# - Actual Time of Completion: 2269.17 seconds
# - Expected Coordinates: (1, 3)
# - Actual Coordinates: (0, 3)
#
# The robot is ahead of schedule by 0.8299999999999272 seconds.
# It is now located at position (0, 3). It has moved 1 units to the left and 0 units downward from the expected position ((1, 3)).
#
# --------------------------------------------------
# Raw data received from server: ['197', '1', '2', '2280.0', '20']
# SHMM Array: 216
# HMM Array: [196, 1, 2, 2280.0, 48]
# RMM Array: [196, 0, 2, 2277.56, 216]
# Updated HMM Array: [[0, 0, 2, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2280.0 seconds
# - Actual Time of Completion: 2277.56 seconds
# - Expected Coordinates: (1, 2)
# - Actual Coordinates: (0, 2)
#
# The robot is ahead of schedule by 2.4400000000000546 seconds.
# It is now located at position (0, 2). It has moved 1 units to the left and 0 units downward from the expected position ((1, 2)).
#
# --------------------------------------------------
# Raw data received from server: ['198', '1', '1', '2290.0', '19']
# SHMM Array: 216
# HMM Array: [197, 1, 1, 2290.0, 48]
# RMM Array: [197, 0, 1, 2285.35, 216]
# Updated HMM Array: [[0, 0, 1, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2290.0 seconds
# - Actual Time of Completion: 2285.35 seconds
# - Expected Coordinates: (1, 1)
# - Actual Coordinates: (0, 1)
#
# The robot is ahead of schedule by 4.650000000000091 seconds.
# It is now located at position (0, 1). It has moved 1 units to the left and 0 units downward from the expected position ((1, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['199', '1', '0', '2300.0', '18']
# SHMM Array: 216
# HMM Array: [198, 1, 0, 2300.0, 48]
# RMM Array: [198, 0, 0, 2298.58, 216]
# Updated HMM Array: [[0, 0, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2300.0 seconds
# - Actual Time of Completion: 2298.58 seconds
# - Expected Coordinates: (1, 0)
# - Actual Coordinates: (0, 0)
#
# The robot is ahead of schedule by 1.4200000000000728 seconds.
# It is now located at position (0, 0). It has moved 1 units to the left and 0 units downward from the expected position ((1, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['200', '2', '0', '2310.0', '17']
# SHMM Array: 216
# HMM Array: [199, 2, 0, 2310.0, 48]
# RMM Array: [199, 1, 0, 2306.92, 216]
# Updated HMM Array: [[0, 1, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2310.0 seconds
# - Actual Time of Completion: 2306.92 seconds
# - Expected Coordinates: (2, 0)
# - Actual Coordinates: (1, 0)
#
# The robot is ahead of schedule by 3.0799999999999272 seconds.
# It is now located at position (1, 0). It has moved 1 units to the left and 0 units downward from the expected position ((2, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['201', '3', '0', '2320.0', '16']
# SHMM Array: 216
# HMM Array: [200, 3, 0, 2320.0, 48]
# RMM Array: [200, 3, 0, 2319.08, 216]
# Updated HMM Array: [[0, 3, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2320.0 seconds
# - Actual Time of Completion: 2319.08 seconds
# - Expected Coordinates: (3, 0)
# - Actual Coordinates: (3, 0)
#
# The robot is ahead of schedule by 0.9200000000000728 seconds.
# It is now located at position (3, 0).
#
# --------------------------------------------------
# Raw data received from server: ['202', '4', '0', '2330.0', '15']
# SHMM Array: 216
# HMM Array: [201, 4, 0, 2330.0, 48]
# RMM Array: [201, 4, 0, 2332.95, 216]
# Updated HMM Array: [[0, 4, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2330.0 seconds
# - Actual Time of Completion: 2332.95 seconds
# - Expected Coordinates: (4, 0)
# - Actual Coordinates: (4, 0)
#
# The robot is currently experiencing a delay of 2.949999999999818 seconds.
# It is now located at position (4, 0).
#
# --------------------------------------------------
# Raw data received from server: ['203', '5', '0', '2340.0', '14']
# SHMM Array: 216
# HMM Array: [202, 5, 0, 2340.0, 48]
# RMM Array: [202, 4, 0, 2334.23, 216]
# Updated HMM Array: [[0, 4, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2340.0 seconds
# - Actual Time of Completion: 2334.23 seconds
# - Expected Coordinates: (5, 0)
# - Actual Coordinates: (4, 0)
#
# The robot is ahead of schedule by 5.769999999999982 seconds.
# It is now located at position (4, 0). It has moved 1 units to the left and 0 units downward from the expected position ((5, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['204', '6', '0', '2350.0', '13']
# SHMM Array: 216
# HMM Array: [203, 6, 0, 2350.0, 48]
# RMM Array: [203, 5, 0, 2352.31, 216]
# Updated HMM Array: [[0, 5, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2350.0 seconds
# - Actual Time of Completion: 2352.31 seconds
# - Expected Coordinates: (6, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is currently experiencing a delay of 2.3099999999999454 seconds.
# It is now located at position (5, 0). It has moved 1 units to the left and 0 units downward from the expected position ((6, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['205', '7', '0', '2360.0', '12']
# SHMM Array: 216
# HMM Array: [204, 7, 0, 2360.0, 48]
# RMM Array: [204, 5, 0, 2359.54, 216]
# Updated HMM Array: [[0, 5, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2360.0 seconds
# - Actual Time of Completion: 2359.54 seconds
# - Expected Coordinates: (7, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is ahead of schedule by 0.4600000000000364 seconds.
# It is now located at position (5, 0). It has moved 2 units to the left and 0 units downward from the expected position ((7, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['206', '8', '0', '2370.0', '11']
# SHMM Array: 216
# HMM Array: [205, 8, 0, 2370.0, 48]
# RMM Array: [205, 5, 0, 2370.3, 216]
# Updated HMM Array: [[0, 5, 0, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2370.0 seconds
# - Actual Time of Completion: 2370.3 seconds
# - Expected Coordinates: (8, 0)
# - Actual Coordinates: (5, 0)
#
# The robot is currently experiencing a delay of 0.3000000000001819 seconds.
# It is now located at position (5, 0). It has moved 3 units to the left and 0 units downward from the expected position ((8, 0)).
#
# --------------------------------------------------
# Raw data received from server: ['207', '8', '1', '2380.0', '10']
# SHMM Array: 216
# HMM Array: [206, 8, 1, 2380.0, 48]
# RMM Array: [206, 5, 1, 2378.51, 216]
# Updated HMM Array: [[0, 5, 1, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2380.0 seconds
# - Actual Time of Completion: 2378.51 seconds
# - Expected Coordinates: (8, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 1.4899999999997817 seconds.
# It is now located at position (5, 1). It has moved 3 units to the left and 0 units downward from the expected position ((8, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['208', '7', '1', '2390.0', '9']
# SHMM Array: 216
# HMM Array: [207, 7, 1, 2390.0, 48]
# RMM Array: [207, 5, 1, 2382.46, 216]
# Updated HMM Array: [[0, 5, 1, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2390.0 seconds
# - Actual Time of Completion: 2382.46 seconds
# - Expected Coordinates: (7, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 7.539999999999964 seconds.
# It is now located at position (5, 1). It has moved 2 units to the left and 0 units downward from the expected position ((7, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['209', '6', '1', '2400.0', '8']
# SHMM Array: 216
# HMM Array: [208, 6, 1, 2400.0, 48]
# RMM Array: [208, 5, 1, 2399.63, 216]
# Updated HMM Array: [[0, 5, 1, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2400.0 seconds
# - Actual Time of Completion: 2399.63 seconds
# - Expected Coordinates: (6, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 0.36999999999989086 seconds.
# It is now located at position (5, 1). It has moved 1 units to the left and 0 units downward from the expected position ((6, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['210', '5', '1', '2410.0', '7']
# SHMM Array: 216
# HMM Array: [209, 5, 1, 2410.0, 48]
# RMM Array: [209, 4, 1, 2405.73, 216]
# Updated HMM Array: [[0, 4, 1, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2410.0 seconds
# - Actual Time of Completion: 2405.73 seconds
# - Expected Coordinates: (5, 1)
# - Actual Coordinates: (4, 1)
#
# The robot is ahead of schedule by 4.269999999999982 seconds.
# It is now located at position (4, 1). It has moved 1 units to the left and 0 units downward from the expected position ((5, 1)).
#
# --------------------------------------------------
# Raw data received from server: ['211', '5', '2', '2420.0', '6']
# SHMM Array: 216
# HMM Array: [210, 5, 2, 2420.0, 48]
# RMM Array: [210, 5, 2, 2419.59, 216]
# Updated HMM Array: [[0, 5, 2, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2420.0 seconds
# - Actual Time of Completion: 2419.59 seconds
# - Expected Coordinates: (5, 2)
# - Actual Coordinates: (5, 2)
#
# The robot is ahead of schedule by 0.4099999999998545 seconds.
# It is now located at position (5, 2).
#
# --------------------------------------------------
# Raw data received from server: ['212', '5', '3', '2430.0', '5']
# SHMM Array: 216
# HMM Array: [211, 5, 3, 2430.0, 48]
# RMM Array: [211, 4, 3, 2429.97, 216]
# Updated HMM Array: [[0, 4, 3, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2430.0 seconds
# - Actual Time of Completion: 2429.97 seconds
# - Expected Coordinates: (5, 3)
# - Actual Coordinates: (4, 3)
#
# The robot is ahead of schedule by 0.03000000000020009 seconds.
# It is now located at position (4, 3). It has moved 1 units to the left and 0 units downward from the expected position ((5, 3)).
#
# --------------------------------------------------
# Raw data received from server: ['213', '5', '4', '2440.0', '4']
# SHMM Array: 216
# HMM Array: [212, 5, 4, 2440.0, 48]
# RMM Array: [212, 5, 3, 2441.18, 216]
# Updated HMM Array: [[0, 5, 3, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2440.0 seconds
# - Actual Time of Completion: 2441.18 seconds
# - Expected Coordinates: (5, 4)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 1.1799999999998363 seconds.
# It is now located at position (5, 3). It has moved 0 units to the left and 1 units downward from the expected position ((5, 4)).
#
# --------------------------------------------------
# Raw data received from server: ['214', '5', '3', '2450.0', '3']
# SHMM Array: 216
# HMM Array: [213, 5, 3, 2450.0, 48]
# RMM Array: [213, 4, 3, 2449.58, 216]
# Updated HMM Array: [[0, 4, 3, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2450.0 seconds
# - Actual Time of Completion: 2449.58 seconds
# - Expected Coordinates: (5, 3)
# - Actual Coordinates: (4, 3)
#
# The robot is ahead of schedule by 0.42000000000007276 seconds.
# It is now located at position (4, 3). It has moved 1 units to the left and 0 units downward from the expected position ((5, 3)).
#
# --------------------------------------------------
# Raw data received from server: ['215', '5', '3', '2450.0', '2']
# SHMM Array: 216
# HMM Array: [214, 5, 3, 2450.0, 48]
# RMM Array: [214, 5, 3, 2454.92, 216]
# Updated HMM Array: [[0, 5, 3, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2450.0 seconds
# - Actual Time of Completion: 2454.92 seconds
# - Expected Coordinates: (5, 3)
# - Actual Coordinates: (5, 3)
#
# The robot is currently experiencing a delay of 4.920000000000073 seconds.
# It is now located at position (5, 3).
#
# --------------------------------------------------
# Raw data received from server: ['216', '5', '2', '2460.0', '1']
# SHMM Array: 216
# HMM Array: [215, 5, 2, 2460.0, 48]
# RMM Array: [215, 4, 2, 2461.31, 216]
# Updated HMM Array: [[0, 4, 2, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2460.0 seconds
# - Actual Time of Completion: 2461.31 seconds
# - Expected Coordinates: (5, 2)
# - Actual Coordinates: (4, 2)
#
# The robot is currently experiencing a delay of 1.3099999999999454 seconds.
# It is now located at position (4, 2). It has moved 1 units to the left and 0 units downward from the expected position ((5, 2)).
#
# --------------------------------------------------
# Raw data received from server: ['217', '5', '1', '2470.0', '0']
# SHMM Array: 216
# HMM Array: [216, 5, 1, 2470.0, 48]
# RMM Array: [216, 5, 1, 2469.33, 216]
# Updated HMM Array: [[0, 5, 1, None, 384]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 2470.0 seconds
# - Actual Time of Completion: 2469.33 seconds
# - Expected Coordinates: (5, 1)
# - Actual Coordinates: (5, 1)
#
# The robot is ahead of schedule by 0.6700000000000728 seconds.
# It is now located at position (5, 1).
#
# --------------------------------------------------
# Connection closed
# Processing completed. Stopping client.

# %%
import asyncio
import websockets
import numpy as np

# Global variables to store the arrays
hmm_array = None
rmm_array = None

# Adjusted RMM array generation for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

# Define the uncertainty factors
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    # Calculate the L1 norm (absolute difference)
    norm = np.abs(np.array(array2) - np.array(array1))
    return norm

# Function to perform a Bayesian probabilistic update
def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value

# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template

def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        messages.append(delay_message)  # Append formatted delay message to messages list
    return messages

# Function to dynamically update based on deviations and given logics
def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    updated_hmm_array = []  # Initialize updated_hmm_array
    current_hmm_mission_time = hmm_arrays[0][4]  # Use the mission time from hmm_arrays

    # Use the updated position from rmm
    updated_pos1 = rmm_arrays[0][1]  # First position from rmm
    updated_pos2 = rmm_arrays[0][2]  # Second position from rmm

    # Calculate the mission time deviation
    mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[0][4]])
    
    # Get the first element of the deviation for updating
    mission_time_deviation_value = mission_time_deviation[0]

    # Set a dynamic threshold for mission time
    dynamic_threshold_mission_time = 2

    hmm_pos1 = hmm_arrays[0][1]
    hmm_pos2 = hmm_arrays[0][2]
    rmm_pos1 = rmm_arrays[0][1]
    rmm_pos2 = rmm_arrays[0][2]
    hmm_time = hmm_arrays[0][3]
    rmm_time = rmm_arrays[0][3]

    message = generate_communication_message(mission_time_deviation_value, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)

    # Update mission time using the update logic
    updated_mission_time = update_logic_functions[0](current_hmm_mission_time, mission_time_deviation_value,
                                                       dynamic_threshold_mission_time, uncertainty_factor_time)

    # Append the updated values to the updated_hmm_array
    updated_hmm_array.append([0, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

    return updated_hmm_array, message

# Define the update logics
update_logics = [bayesian_probabilistic_update_general]

# Client-side WebSocket logic
async def websocket_client():
    global hmm_array, rmm_array  # Declare global variables
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0
    message_count = 0  # Initialize message count

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        while True:  # Loop to receive and send data
            # Prepare data for sending
            if hmm_array is not None and rmm_array is not None:
                # Create the message with the current timestep and data
                message = {
                    "timestep": timestep,
                    "hmm_data": hmm_array,
                    "rmm_data": rmm_array
                }
                
                # Send the message to the server
                await websocket.send(str(message))
                print(f"Sent: {message}")

                # Wait for a response from the server
                response = await websocket.recv()
                print(f"Received: {response}")

                # Here you can process the response as needed
                # For example, update the global arrays with the received data
                response_data = eval(response)  # Use `eval` cautiously; ensure data is safe
                hmm_array = response_data.get("hmm_data", hmm_array)
                rmm_array = response_data.get("rmm_data", rmm_array)

                # Increment timestep and message count
                timestep += 1
                message_count += 1

                # Optionally, add a delay to control the rate of communication
                await asyncio.sleep(1)  # Delay for 1 second before the next message

# Entry point for the WebSocket client
if __name__ == "__main__":
    # Start the WebSocket client
    asyncio.run(websocket_client())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 225
#     222 # Entry point for the WebSocket client
#     223 if __name__ == "__main__":
#     224     # Start the WebSocket client
# --> 225     asyncio.run(websocket_client())
#
# File /usr/lib/python3.8/asyncio/runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import numpy as np

def calculate_l1_norm(value1, value2):
    # Calculate the L1 norm (Manhattan distance)
    return np.sum(np.abs(np.array(value1) - np.array(value2)))

def calculate_mission_time_deviation(rmm_arrays):
    current_hmm_mission_time = rmm_arrays[0][4]  # Use mission time from the first RMM array
    mission_time_deviations = []

    # Iterate through each RMM array to calculate deviations
    for j in range(len(rmm_arrays)):
        # Calculate the mission time deviation for the current RMM array
        mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[j][4]])
        mission_time_deviations.append(mission_time_deviation)

    return mission_time_deviations

# Example usage
rmm_arrays = np.array([[0, 1, 2, 3, 10], 
                       [0, 1, 2, 3, 12], 
                       [0, 1, 2, 3, 15], 
                       [0, 1, 2, 3, 8], 
                       [0, 1, 2, 3, 20]])  # Example RMM arrays

# Calculate mission time deviations
deviations = calculate_mission_time_deviation(rmm_arrays)

# Print the results
for idx, deviation in enumerate(deviations):
    print(f"Mission time deviation for RMM array {idx}: {deviation}")
# Out:
# Mission time deviation for RMM array 0: 0
# Mission time deviation for RMM array 1: 2
# Mission time deviation for RMM array 2: 5
# Mission time deviation for RMM array 3: 2
# Mission time deviation for RMM array 4: 10

# %%
import socket
import numpy as np

# Define the uncertainty factors
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    # Calculate the L1 norm (absolute difference)
    norm = np.abs(np.array(array2) - np.array(array1))
    return norm

# Function to perform a Bayesian probabilistic update
def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value

# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template

def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        messages.append(delay_message)  # Append formatted delay message to messages list
    return messages

# Function to dynamically update based on deviations and given logics
def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    updated_hmm_array = []  # Initialize updated_hmm_array
    current_hmm_mission_time = hmm_arrays[0][4]  # Use the mission time from hmm_arrays

    # Print the current mission time for debugging
    print("Current HMM Mission Time:", current_hmm_mission_time)

    # Use the updated position from rmm
    updated_pos1 = rmm_arrays[0][1]  # First position from rmm
    updated_pos2 = rmm_arrays[0][2]  # Second position from rmm

    # Calculate the mission time deviation
    mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[0][4]])
    print("Mission Time Deviation:", mission_time_deviation)
    
    # Get the first element of the deviation for updating
    mission_time_deviation_value = mission_time_deviation[0]

    # Set a dynamic threshold for mission time
    dynamic_threshold_mission_time = 2

    hmm_pos1 = hmm_arrays[0][1]
    hmm_pos2 = hmm_arrays[0][2]
    rmm_pos1 = rmm_arrays[0][1]
    rmm_pos2 = rmm_arrays[0][2]
    hmm_time = hmm_arrays[0][3]
    rmm_time = rmm_arrays[0][3]

    message = generate_communication_message(mission_time_deviation_value, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)

    # Update mission time using the update logic
    updated_mission_time = update_logic_functions[0](current_hmm_mission_time, mission_time_deviation_value,
                                                       dynamic_threshold_mission_time, uncertainty_factor_time)
    print("Updated Mission Time:", updated_mission_time)

    # Append the updated values to the updated_hmm_array
    updated_hmm_array.append([0, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

    return updated_hmm_array, message


def main():
    # Create a socket object
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    
    # Define the server address and port
    server_address = ('localhost', 8765)  # Change as necessary
    client_socket.connect(server_address)

    try:
        while True:
            # Receive data from the server
            data = client_socket.recv(1024).decode('utf-8')
            if not data:
                break
            
            # Parse the received data to create hmm_array and rmm_array
            # Assuming the data format is: "hmm_array_value1,hmm_array_value2,hmm_array_value3,hmm_array_value4,hmm_array_value5|rmm_array_value1,rmm_array_value2,rmm_array_value3,rmm_array_value4,rmm_array_value5"
            hmm_data, rmm_data = data.split('|')
            hmm_array = [list(map(float, hmm_data.split(',')))]
            rmm_array = [list(map(float, rmm_data.split(',')))]

            # Define the update logics
            update_logics = [bayesian_probabilistic_update_general]

            # Call the function
            updated_hmm_array, message = dynamic_deviation_threshold_multi_logic(
                hmm_array, rmm_array, update_logics, uncertainty_factor_pos, uncertainty_factor_time
            )

            print("HMM Array:", hmm_array)
            print("RMM Array:", rmm_array)

            # Print the updated hmm_array
            print("Updated HMM Array:", updated_hmm_array)

            formatted_message = "\n".join(message)
            print(formatted_message)

    finally:
        client_socket.close()

if __name__ == "__main__":
    main()

# %%
# I have 

hmm_array = [0, 4, 3, 10.0, 37]

rmm_array = [0, 4, 3, 12.45, 48]
 stored as array values. I want to use them to generate one communication message


# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    norm = (np.array(array2) - np.array(array1))
    return norm


def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Maximization step: update the parameter using the expected value
    updated_value = expected_value

    # Update only if the deviation crosses the threshold
    updated_value = updated_value if abs(deviation) > threshold else original_value
    return updated_value


# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template


def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        # print(delay_message)
        messages.append(delay_message)  # Append formatted delay message to messages list
        # print(messages)
    return messages



def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    all_updated_hmm_arrays = []
    all_communication_messages = []  # Initialize list to collect all communication messages

    for i, update_logic in enumerate(update_logic_functions):

        mission_time_deviation = calculate_l1_norm([hmm_arrays[i][4]], [rmm_arrays[i][4]])[0]


        # dynamic_threshold_mission_time = 10 # 11 stars # dataset low threshold high sensitivity 3
        # dynamic_threshold_mission_time = 15 # 8 stars # dataset medium 2
        dynamic_threshold_mission_time = 20 # 6 stars # dataset high threshold low sensitivity 1


        # dynamic_threshold_mission_time = 40 # 8 stars # 20 datasize jiming


        updated_hmm_array = []
        communication_messages = []  # Initialize list to collect communication messages for this logic iteration

        current_hmm_mission_time = rmm_arrays[0][4]

        for j in range(len(hmm_arrays)):
            updated_pos1 = rmm_arrays[j][1]
            updated_pos2 = rmm_arrays[j][2]
            mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[j][4]])[0]

            hmm_pos1 = hmm_arrays[j][1]
            hmm_pos2 = hmm_arrays[j][2]
            rmm_pos1 = rmm_arrays[j][1]
            rmm_pos2 = rmm_arrays[j][2]
            hmm_time = hmm_arrays[j][3]
            rmm_time = rmm_arrays[j][3]

            messages = generate_communication_message(mission_time_deviation, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)
            communication_messages.extend(messages)

            updated_mission_time = update_logic(current_hmm_mission_time, mission_time_deviation,
                                               dynamic_threshold_mission_time, uncertainty_factor_time)
            current_hmm_mission_time = updated_mission_time

            updated_hmm_array.append([j, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

        all_updated_hmm_arrays.append(np.array(updated_hmm_array))  # Append updated hmm_array to list
        all_communication_messages.append(communication_messages)  # Append communication messages to list for this logic

    return all_updated_hmm_arrays, all_communication_messages  # Return both arrays and messages

def save_to_csv(filename, data):
    with open(filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerows(data)



if __name__ == "__main__":
    update_logics = [bayesian_probabilistic_update_general]

    uncertainty_factor_pos = 0.05
    uncertainty_factor_time = 0.01

    shmm_data = []

    # Read data from CSV file and format it
    # with open("robot_data_20_jiming.csv", 'r') as csvfile:
    with open("robot_data_10_jiming.csv", 'r') as csvfile:
        csv_reader = csv.reader(csvfile, delimiter='\t')
        timestep = 0
        for row in csv_reader:
            first_state = int(row[1])
            second_state = int(row[2])
            time_elapsed = float(row[3])
            steps_remaining = int(row[4])
            mission_time = timestep + steps_remaining
            shmm_data.append(((first_state, second_state), time_elapsed, mission_time))
            timestep += 1

    rmm_arrays = generate_rmm_array(shmm_data)
    shmm_data_with_index = [[i, pose[0][0], pose[0][1], pose[1], pose[2]] for i, pose in enumerate(shmm_data)]
    hmm_arrays = [[arr[0], arr[1], arr[2], round(arr[3], 2), 37] for arr in shmm_data_with_index]

    all_updated_arrays, communication_details = dynamic_deviation_threshold_multi_logic(
        hmm_arrays, rmm_arrays, update_logics, uncertainty_factor_pos, uncertainty_factor_time
    )

# %%
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    norm = (np.array(array2) - np.array(array1))
    return norm


def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Maximization step: update the parameter using the expected value
    updated_value = expected_value

    # Update only if the deviation crosses the threshold
    updated_value = updated_value if abs(deviation) > threshold else original_value
    return updated_value



def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    all_updated_hmm_arrays = []
    all_communication_messages = []  # Initialize list to collect all communication messages

    for i, update_logic in enumerate(update_logic_functions):

        mission_time_deviation = calculate_l1_norm([hmm_arrays[i][4]], [rmm_arrays[i][4]])[0]


        # dynamic_threshold_mission_time = 10 # 11 stars # dataset low threshold high sensitivity 3
        # dynamic_threshold_mission_time = 15 # 8 stars # dataset medium 2
        dynamic_threshold_mission_time = 20 # 6 stars # dataset high threshold low sensitivity 1


        # dynamic_threshold_mission_time = 40 # 8 stars # 20 datasize jiming


        updated_hmm_array = []
        communication_messages = []  # Initialize list to collect communication messages for this logic iteration

        current_hmm_mission_time = rmm_arrays[0][4]

        for j in range(len(hmm_arrays)):
            updated_pos1 = rmm_arrays[j][1]
            updated_pos2 = rmm_arrays[j][2]
            mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[j][4]])[0]

            hmm_pos1 = hmm_arrays[j][1]
            hmm_pos2 = hmm_arrays[j][2]
            rmm_pos1 = rmm_arrays[j][1]
            rmm_pos2 = rmm_arrays[j][2]
            hmm_time = hmm_arrays[j][3]
            rmm_time = rmm_arrays[j][3]

            # messages = generate_communication_message(mission_time_deviation, dynamic_threshold_mission_time,
            #                                          hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)
            # communication_messages.extend(messages)

            updated_mission_time = update_logic(current_hmm_mission_time, mission_time_deviation,
                                               dynamic_threshold_mission_time, uncertainty_factor_time)
            current_hmm_mission_time = updated_mission_time

            updated_hmm_array.append([j, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

        all_updated_hmm_arrays.append(np.array(updated_hmm_array))  # Append updated hmm_array to list
        # all_communication_messages.append(communication_messages)  # Append communication messages to list for this logic

    # return all_updated_hmm_arrays, all_communication_messages  # Return both arrays and messages
    return all_updated_hmm_arrays  # Return both arrays and messages



   all_updated_arrays = dynamic_deviation_threshold_multi_logic(
        hmm_arrays, rmm_arrays, update_logics, uncertainty_factor_pos, uncertainty_factor_time
    )

# %%
hmm_array
# Out:
# [0, 4, 3, 10.0, 37]

# %%
rmm_array
# Out:
# [0, 4, 3, 12.45, 48]

# %%
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    norm = (np.array(array2) - np.array(array1))
    return norm


def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Maximization step: update the parameter using the expected value
    updated_value = expected_value

    # Update only if the deviation crosses the threshold
    updated_value = updated_value if abs(deviation) > threshold else original_value
    return updated_value



def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    all_updated_hmm_arrays = []
    all_communication_messages = []  # Initialize list to collect all communication messages

    for i, update_logic in enumerate(update_logic_functions):

        mission_time_deviation = calculate_l1_norm([hmm_arrays[i][4]], [rmm_arrays[i][4]])[0]


        # dynamic_threshold_mission_time = 10 # 11 stars # dataset low threshold high sensitivity 3
        # dynamic_threshold_mission_time = 15 # 8 stars # dataset medium 2
        dynamic_threshold_mission_time = 20 # 6 stars # dataset high threshold low sensitivity 1


        # dynamic_threshold_mission_time = 40 # 8 stars # 20 datasize jiming


        updated_hmm_array = []
        communication_messages = []  # Initialize list to collect communication messages for this logic iteration

        current_hmm_mission_time = rmm_arrays[0][4]

        for j in range(len(hmm_arrays)):
            updated_pos1 = rmm_arrays[j][1]
            updated_pos2 = rmm_arrays[j][2]
            mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[j][4]])[0]

            hmm_pos1 = hmm_arrays[j][1]
            hmm_pos2 = hmm_arrays[j][2]
            rmm_pos1 = rmm_arrays[j][1]
            rmm_pos2 = rmm_arrays[j][2]
            hmm_time = hmm_arrays[j][3]
            rmm_time = rmm_arrays[j][3]



            updated_mission_time = update_logic(current_hmm_mission_time, mission_time_deviation,
                                               dynamic_threshold_mission_time, uncertainty_factor_time)
            current_hmm_mission_time = updated_mission_time

            updated_hmm_array.append([j, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

        all_updated_hmm_arrays.append(np.array(updated_hmm_array))  # Append updated hmm_array to list

    return all_updated_hmm_arrays  



all_updated_arrays = dynamic_deviation_threshold_multi_logic(
        hmm_arrays, rmm_arrays, update_logics, uncertainty_factor_pos, uncertainty_factor_time
    )


all_updated_arrays
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 72
#      65         all_updated_hmm_arrays.append(np.array(updated_hmm_array))  # Append updated hmm_array to list
#      67     return all_updated_hmm_arrays
#      71 all_updated_arrays = dynamic_deviation_threshold_multi_logic(
# ---> 72         hmm_arrays, rmm_arrays, update_logics, uncertainty_factor_pos, uncertainty_factor_time
#      73     )
#      76 all_updated_arrays
#
# NameError: name 'hmm_arrays' is not defined

# %%
import numpy as np

uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    norm = (np.array(array2) - np.array(array1))
    return norm

def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value

def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):

    for i, update_logic in enumerate(update_logic_functions):
        updated_hmm_array = []
        current_hmm_mission_time = rmm_arrays[0][4]  # Use the first row's mission time
        print(current_hmm_mission_time)



        

        updated_pos1 = rmm_arrays[1]
        updated_pos2 = rmm_arrays[2]
        mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[4]])
        print(mission_time_deviation)
        print(mission_time_deviation[0])

        
        dynamic_threshold_mission_time = 20  # Set your threshold

        updated_mission_time = update_logic(current_hmm_mission_time, mission_time_deviation,
                                                 dynamic_threshold_mission_time, uncertainty_factor_time)
        current_hmm_mission_time = updated_mission_time

        updated_hmm_array.append([j, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])


    return updated_hmm_array

# Define the single row as 2D arrays
hmm_array = [[0, 4, 3, 10.0, 37]]  # Single row for hmm_array
rmm_array = [[0, 4, 3, 12.45, 48]]  # Single row for rmm_array

update_logics = [bayesian_probabilistic_update_general]

# Call the function
updated_hmm_array = dynamic_deviation_threshold_multi_logic(
    hmm_array, rmm_array, update_logics, uncertainty_factor_pos, uncertainty_factor_time
)

# Print the updated hmm_array
updated_hmm_array
# Out:
# 48
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 55
#      52 update_logics = [bayesian_probabilistic_update_general]
#      54 # Call the function
# ---> 55 updated_hmm_array = dynamic_deviation_threshold_multi_logic(
#      56     hmm_array, rmm_array, update_logics, uncertainty_factor_pos, uncertainty_factor_time
#      57 )
#      59 # Print the updated hmm_array
#      60 updated_hmm_array
#
# Cell In[69], line 30, in dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time)
#      23 current_hmm_mission_time = rmm_arrays[0][4]  # Use the first row's mission time
#      24 print(current_hmm_mission_time)
# ---> 30 updated_pos1 = rmm_arrays[1]
#      31 updated_pos2 = rmm_arrays[2]
#      32 mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[4]])
#
# IndexError: list index out of range

# %%
import numpy as np

# Define the uncertainty factors
uncertainty_factor_pos = 0.05
uncertainty_factor_time = 0.01

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    # Calculate the L1 norm (absolute difference)
    norm = np.abs(np.array(array2) - np.array(array1))
    return norm

# Function to perform a Bayesian probabilistic update
def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Update only if the deviation crosses the threshold
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value


# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template


def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        # print(delay_message)
        messages.append(delay_message)  # Append formatted delay message to messages list
        # print(messages)
    return messages





# Function to dynamically update based on deviations and given logics
def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    updated_hmm_array = []  # Initialize updated_hmm_array
    current_hmm_mission_time = hmm_arrays[0][4]  # Use the mission time from hmm_arrays

    # Print the current mission time for debugging
    print("Current HMM Mission Time:", current_hmm_mission_time)

    # Use the updated position from rmm
    updated_pos1 = rmm_arrays[0][1]  # First position from rmm
    updated_pos2 = rmm_arrays[0][2]  # Second position from rmm

    # Calculate the mission time deviation
    mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[0][4]])
    print("Mission Time Deviation:", mission_time_deviation)
    
    # Get the first element of the deviation for updating
    mission_time_deviation_value = mission_time_deviation[0]

    # Set a dynamic threshold for mission time
    dynamic_threshold_mission_time = 2



    hmm_pos1 = hmm_arrays[0][1]
    hmm_pos2 = hmm_arrays[0][2]
    rmm_pos1 = rmm_arrays[0][1]
    rmm_pos2 = rmm_arrays[0][2]
    hmm_time = hmm_arrays[0][3]
    rmm_time = rmm_arrays[0][3]

    message = generate_communication_message(mission_time_deviation_value, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)


    
    # Update mission time using the update logic
    updated_mission_time = update_logic_functions[0](current_hmm_mission_time, mission_time_deviation_value,
                                                       dynamic_threshold_mission_time, uncertainty_factor_time)
    print("Updated Mission Time:", updated_mission_time)

    # Append the updated values to the updated_hmm_array
    updated_hmm_array.append([0, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

    return updated_hmm_array, message





# Define the single row as 2D arrays
hmm_array = [[0, 4, 3, 10.0, 37]]  # Single row for hmm_array
rmm_array = [[0, 4, 3, 12.45, 48]]  # Single row for rmm_array

# Define the update logics
update_logics = [bayesian_probabilistic_update_general]

# Call the function
updated_hmm_array, message = dynamic_deviation_threshold_multi_logic(
    hmm_array, rmm_array, update_logics, uncertainty_factor_pos, uncertainty_factor_time
)

print(" HMM Array:", hmm_array)
print(" RMM Array:", rmm_array)


# Print the updated hmm_array
print("Updated HMM Array:", updated_hmm_array)

formatted_message = "\n".join(message)
print(formatted_message)
# Out:
# Current HMM Mission Time: 37
# Mission Time Deviation: [11]
# Updated Mission Time: 48
#  HMM Array: [[0, 4, 3, 10.0, 37]]
#  RMM Array: [[0, 4, 3, 12.45, 48]]
# Updated HMM Array: [[0, 4, 3, None, 48]]
# --------------------------------------------------
# Commander,
#
# Robot 1's mission status update:
# - Estimated Time of Completion: 10.0 seconds
# - Actual Time of Completion: 12.45 seconds
# - Expected Coordinates: (4, 3)
# - Actual Coordinates: (4, 3)
#
# The robot is currently experiencing a delay of 2.4499999999999993 seconds.
# It is now located at position (4, 3).
#
# --------------------------------------------------

# %%
# all rows of data one after the other

# %%
import asyncio
import websockets
import numpy as np

# Adjusted RMM array generation for a single row of SHMM data with index
def generate_rmm_array_for_row(shmm_row, index):
    position_values = shmm_row[0]
    time_value = shmm_row[1]
    mission_time_value = shmm_row[2]
    
    # Add noise to position and time
    position_noise = np.random.normal(0, 1)
    time_noise = np.random.normal(0, 3)

    # Process the single row to generate the RMM array
    position_value1 = int(np.round(np.abs(position_values[0] + position_noise)))
    position_value2 = int(np.round(np.abs(position_values[1] + np.random.normal(0, 0.1))))
    time_taken = round((np.abs(time_value + time_noise)), 2)
    mission_tim = int(mission_time_value)

    # Clip position values to be within specified limits
    position_value1 = np.clip(position_value1, 0, 5)
    position_value2 = np.clip(position_value2, 0, 3)

    # Generate the RMM array for this specific row, including the index
    rmm_array = [index, position_value1, position_value2, time_taken, mission_tim]

    return rmm_array

# Client-side WebSocket logic
async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    # Connect to the server
    async with websockets.connect(uri) as websocket:
        try:
            while True:
                # Receive one row of data from the server
                data_from_server = await websocket.recv()
                
                # Print the raw data received from the server
                print(f"Raw data received from server: {data_from_server}")
                
                # Parse the received data (convert string to list)
                row = eval(data_from_server)  # Convert string back to list
                
                # Extract data from the row
                first_state = int(row[1])
                second_state = int(row[2])
                time_elapsed = float(row[3])
                steps_remaining = int(row[4])
                mission_time = timestep + steps_remaining
                
                # Prepare the SHMM data tuple for a single row
                shmm_row = ((first_state, second_state), time_elapsed, mission_time)

                # Generate RMM array for the current row (with index)
                rmm_array = generate_rmm_array_for_row(shmm_row, timestep)
                
                # Convert the current processed row into HMM array format (with index)
                hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]  # 37 as constant
                
                # Print the generated RMM and HMM arrays
                print(f"Generated RMM array for row: {rmm_array}")
                print(f"Generated HMM array for row: {hmm_array}")
                
                # Send a confirmation message back to the server
                await websocket.send("Data received and processed")

                # Increment timestep for the next row
                timestep += 1

        except websockets.exceptions.ConnectionClosed:
            print("Connection closed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Generated RMM array for row: [0, 4, 3, 10.04, 48]
# Generated HMM array for row: [0, 4, 3, 10.0, 37]
# Raw data received from server: ['2', '4', '2', '20.0', '47']
# Generated RMM array for row: [1, 5, 2, 18.56, 48]
# Generated HMM array for row: [1, 4, 2, 20.0, 37]
# Raw data received from server: ['3', '4', '1', '30.0', '46']
# Generated RMM array for row: [2, 4, 1, 27.62, 48]
# Generated HMM array for row: [2, 4, 1, 30.0, 37]
# Raw data received from server: ['4', '3', '1', '40.0', '49']
# Generated RMM array for row: [3, 3, 1, 43.4, 52]
# Generated HMM array for row: [3, 3, 1, 40.0, 37]
# Raw data received from server: ['5', '2', '1', '50.0', '52']
# Generated RMM array for row: [4, 3, 1, 53.22, 56]
# Generated HMM array for row: [4, 2, 1, 50.0, 37]
# Raw data received from server: ['6', '1', '1', '60.0', '55']
# Generated RMM array for row: [5, 2, 1, 64.38, 60]
# Generated HMM array for row: [5, 1, 1, 60.0, 37]
# Raw data received from server: ['7', '1', '0', '110.0', '56']
# Generated RMM array for row: [6, 0, 0, 114.43, 62]
# Generated HMM array for row: [6, 1, 0, 110.0, 37]
# Raw data received from server: ['8', '2', '0', '120.0', '55']
# Generated RMM array for row: [7, 3, 0, 119.68, 62]
# Generated HMM array for row: [7, 2, 0, 120.0, 37]
# Raw data received from server: ['9', '3', '0', '130.0', '54']
# Generated RMM array for row: [8, 1, 0, 139.31, 62]
# Generated HMM array for row: [8, 3, 0, 130.0, 37]
# Raw data received from server: ['10', '4', '0', '140.0', '53']
# Generated RMM array for row: [9, 3, 0, 144.76, 62]
# Generated HMM array for row: [9, 4, 0, 140.0, 37]
# Raw data received from server: ['11', '5', '0', '150.0', '52']
# Generated RMM array for row: [10, 4, 0, 151.17, 62]
# Generated HMM array for row: [10, 5, 0, 150.0, 37]
# Raw data received from server: ['12', '6', '0', '160.0', '55']
# Generated RMM array for row: [11, 5, 0, 159.58, 66]
# Generated HMM array for row: [11, 6, 0, 160.0, 37]
# Raw data received from server: ['13', '7', '0', '170.0', '58']
# Generated RMM array for row: [12, 5, 0, 171.15, 70]
# Generated HMM array for row: [12, 7, 0, 170.0, 37]
# Raw data received from server: ['14', '8', '0', '180.0', '61']
# Generated RMM array for row: [13, 5, 0, 178.34, 74]
# Generated HMM array for row: [13, 8, 0, 180.0, 37]
# Raw data received from server: ['15', '9', '0', '190.0', '64']
# Generated RMM array for row: [14, 5, 0, 186.77, 78]
# Generated HMM array for row: [14, 9, 0, 190.0, 37]
# Raw data received from server: ['16', '9', '1', '200.0', '63']
# Generated RMM array for row: [15, 5, 1, 199.22, 78]
# Generated HMM array for row: [15, 9, 1, 200.0, 37]
# Raw data received from server: ['17', '9', '2', '210.0', '62']
# Generated RMM array for row: [16, 5, 2, 204.88, 78]
# Generated HMM array for row: [16, 9, 2, 210.0, 37]
# Raw data received from server: ['18', '9', '3', '220.0', '61']
# Generated RMM array for row: [17, 5, 3, 221.78, 78]
# Generated HMM array for row: [17, 9, 3, 220.0, 37]
# Raw data received from server: ['19', '9', '4', '230.0', '60']
# Generated RMM array for row: [18, 5, 3, 229.91, 78]
# Generated HMM array for row: [18, 9, 4, 230.0, 37]
# Raw data received from server: ['20', '9', '3', '240.0', '69']
# Generated RMM array for row: [19, 5, 3, 241.83, 88]
# Generated HMM array for row: [19, 9, 3, 240.0, 37]
# Raw data received from server: ['21', '9', '2', '250.0', '68']
# Generated RMM array for row: [20, 5, 2, 253.6, 88]
# Generated HMM array for row: [20, 9, 2, 250.0, 37]
# Raw data received from server: ['22', '9', '1', '260.0', '67']
# Generated RMM array for row: [21, 5, 1, 263.84, 88]
# Generated HMM array for row: [21, 9, 1, 260.0, 37]
# Raw data received from server: ['23', '8', '1', '310.0', '66']
# Generated RMM array for row: [22, 5, 1, 310.72, 88]
# Generated HMM array for row: [22, 8, 1, 310.0, 37]
# Raw data received from server: ['24', '7', '1', '320.0', '65']
# Generated RMM array for row: [23, 5, 1, 318.33, 88]
# Generated HMM array for row: [23, 7, 1, 320.0, 37]
# Raw data received from server: ['25', '6', '1', '330.0', '64']
# Generated RMM array for row: [24, 5, 1, 330.32, 88]
# Generated HMM array for row: [24, 6, 1, 330.0, 37]
# Raw data received from server: ['26', '5', '1', '340.0', '63']
# Generated RMM array for row: [25, 4, 1, 337.12, 88]
# Generated HMM array for row: [25, 5, 1, 340.0, 37]
# Raw data received from server: ['27', '5', '2', '350.0', '62']
# Generated RMM array for row: [26, 5, 2, 347.7, 88]
# Generated HMM array for row: [26, 5, 2, 350.0, 37]
# Raw data received from server: ['28', '5', '3', '360.0', '61']
# Generated RMM array for row: [27, 5, 3, 356.55, 88]
# Generated HMM array for row: [27, 5, 3, 360.0, 37]
# Raw data received from server: ['29', '5', '4', '370.0', '60']
# Generated RMM array for row: [28, 4, 3, 369.9, 88]
# Generated HMM array for row: [28, 5, 4, 370.0, 37]
# Raw data received from server: ['30', '5', '3', '380.0', '59']
# Generated RMM array for row: [29, 5, 3, 382.01, 88]
# Generated HMM array for row: [29, 5, 3, 380.0, 37]
# Raw data received from server: ['31', '5', '2', '390.0', '58']
# Generated RMM array for row: [30, 4, 2, 390.58, 88]
# Generated HMM array for row: [30, 5, 2, 390.0, 37]
# Raw data received from server: ['32', '5', '1', '400.0', '57']
# Generated RMM array for row: [31, 3, 1, 398.28, 88]
# Generated HMM array for row: [31, 5, 1, 400.0, 37]
# Raw data received from server: ['33', '6', '1', '410.0', '56']
# Generated RMM array for row: [32, 5, 1, 415.47, 88]
# Generated HMM array for row: [32, 6, 1, 410.0, 37]
# Raw data received from server: ['34', '7', '1', '420.0', '55']
# Generated RMM array for row: [33, 5, 1, 421.83, 88]
# Generated HMM array for row: [33, 7, 1, 420.0, 37]
# Raw data received from server: ['35', '8', '1', '430.0', '54']
# Generated RMM array for row: [34, 5, 1, 434.36, 88]
# Generated HMM array for row: [34, 8, 1, 430.0, 37]
# Raw data received from server: ['36', '9', '1', '440.0', '53']
# Generated RMM array for row: [35, 5, 1, 436.91, 88]
# Generated HMM array for row: [35, 9, 1, 440.0, 37]
# Raw data received from server: ['37', '9', '2', '450.0', '52']
# Generated RMM array for row: [36, 5, 2, 453.35, 88]
# Generated HMM array for row: [36, 9, 2, 450.0, 37]
# Raw data received from server: ['38', '9', '3', '460.0', '51']
# Generated RMM array for row: [37, 5, 3, 458.71, 88]
# Generated HMM array for row: [37, 9, 3, 460.0, 37]
# Raw data received from server: ['39', '9', '4', '470.0', '50']
# Generated RMM array for row: [38, 5, 3, 471.6, 88]
# Generated HMM array for row: [38, 9, 4, 470.0, 37]
# Raw data received from server: ['40', '9', '5', '480.0', '49']
# Generated RMM array for row: [39, 5, 3, 482.21, 88]
# Generated HMM array for row: [39, 9, 5, 480.0, 37]
# Raw data received from server: ['41', '9', '6', '500.0', '67']
# Generated RMM array for row: [40, 5, 3, 502.88, 107]
# Generated HMM array for row: [40, 9, 6, 500.0, 37]
# Raw data received from server: ['42', '9', '7', '510.0', '70']
# Generated RMM array for row: [41, 5, 3, 509.46, 111]
# Generated HMM array for row: [41, 9, 7, 510.0, 37]
# Raw data received from server: ['43', '9', '8', '520.0', '73']
# Generated RMM array for row: [42, 5, 3, 518.45, 115]
# Generated HMM array for row: [42, 9, 8, 520.0, 37]
# Raw data received from server: ['44', '9', '9', '530.0', '76']
# Generated RMM array for row: [43, 5, 3, 529.52, 119]
# Generated HMM array for row: [43, 9, 9, 530.0, 37]
# Raw data received from server: ['45', '8', '9', '540.0', '75']
# Generated RMM array for row: [44, 5, 3, 540.94, 119]
# Generated HMM array for row: [44, 8, 9, 540.0, 37]
# Raw data received from server: ['46', '7', '9', '550.0', '74']
# Generated RMM array for row: [45, 5, 3, 553.0, 119]
# Generated HMM array for row: [45, 7, 9, 550.0, 37]
# Raw data received from server: ['47', '6', '9', '560.0', '73']
# Generated RMM array for row: [46, 5, 3, 555.81, 119]
# Generated HMM array for row: [46, 6, 9, 560.0, 37]
# Raw data received from server: ['48', '5', '9', '570.0', '72']
# Generated RMM array for row: [47, 5, 3, 570.31, 119]
# Generated HMM array for row: [47, 5, 9, 570.0, 37]
# Raw data received from server: ['49', '6', '9', '580.0', '75']
# Generated RMM array for row: [48, 5, 3, 574.66, 123]
# Generated HMM array for row: [48, 6, 9, 580.0, 37]
# Raw data received from server: ['50', '7', '9', '590.0', '78']
# Generated RMM array for row: [49, 5, 3, 587.02, 127]
# Generated HMM array for row: [49, 7, 9, 590.0, 37]
# Raw data received from server: ['51', '8', '9', '600.0', '81']
# Generated RMM array for row: [50, 5, 3, 598.07, 131]
# Generated HMM array for row: [50, 8, 9, 600.0, 37]
# Raw data received from server: ['52', '8', '8', '650.0', '78']
# Generated RMM array for row: [51, 5, 3, 652.32, 129]
# Generated HMM array for row: [51, 8, 8, 650.0, 37]
# Raw data received from server: ['53', '7', '8', '660.0', '77']
# Generated RMM array for row: [52, 5, 3, 656.03, 129]
# Generated HMM array for row: [52, 7, 8, 660.0, 37]
# Raw data received from server: ['54', '6', '8', '670.0', '76']
# Generated RMM array for row: [53, 5, 3, 668.28, 129]
# Generated HMM array for row: [53, 6, 8, 670.0, 37]
# Raw data received from server: ['55', '5', '8', '680.0', '75']
# Generated RMM array for row: [54, 5, 3, 679.97, 129]
# Generated HMM array for row: [54, 5, 8, 680.0, 37]
# Raw data received from server: ['56', '5', '7', '690.0', '74']
# Generated RMM array for row: [55, 5, 3, 694.35, 129]
# Generated HMM array for row: [55, 5, 7, 690.0, 37]
# Raw data received from server: ['57', '5', '6', '700.0', '73']
# Generated RMM array for row: [56, 5, 3, 699.94, 129]
# Generated HMM array for row: [56, 5, 6, 700.0, 37]
# Raw data received from server: ['58', '5', '5', '710.0', '72']
# Generated RMM array for row: [57, 5, 3, 710.89, 129]
# Generated HMM array for row: [57, 5, 5, 710.0, 37]
# Raw data received from server: ['59', '5', '6', '720.0', '71']
# Generated RMM array for row: [58, 5, 3, 721.07, 129]
# Generated HMM array for row: [58, 5, 6, 720.0, 37]
# Raw data received from server: ['60', '5', '7', '730.0', '70']
# Generated RMM array for row: [59, 5, 3, 732.6, 129]
# Generated HMM array for row: [59, 5, 7, 730.0, 37]
# Raw data received from server: ['61', '5', '8', '740.0', '69']
# Generated RMM array for row: [60, 5, 3, 741.86, 129]
# Generated HMM array for row: [60, 5, 8, 740.0, 37]
# Raw data received from server: ['62', '6', '8', '750.0', '68']
# Generated RMM array for row: [61, 5, 3, 746.52, 129]
# Generated HMM array for row: [61, 6, 8, 750.0, 37]
# Raw data received from server: ['63', '7', '8', '760.0', '67']
# Generated RMM array for row: [62, 5, 3, 763.1, 129]
# Generated HMM array for row: [62, 7, 8, 760.0, 37]
# Raw data received from server: ['64', '8', '8', '770.0', '66']
# Generated RMM array for row: [63, 5, 3, 767.86, 129]
# Generated HMM array for row: [63, 8, 8, 770.0, 37]
# Raw data received from server: ['65', '8', '9', '780.0', '65']
# Generated RMM array for row: [64, 5, 3, 778.96, 129]
# Generated HMM array for row: [64, 8, 9, 780.0, 37]
# Raw data received from server: ['66', '7', '9', '790.0', '64']
# Generated RMM array for row: [65, 5, 3, 796.09, 129]
# Generated HMM array for row: [65, 7, 9, 790.0, 37]
# Raw data received from server: ['67', '6', '9', '800.0', '63']
# Generated RMM array for row: [66, 5, 3, 800.1, 129]
# Generated HMM array for row: [66, 6, 9, 800.0, 37]
# Raw data received from server: ['68', '5', '9', '810.0', '62']
# Generated RMM array for row: [67, 5, 3, 806.31, 129]
# Generated HMM array for row: [67, 5, 9, 810.0, 37]
# Raw data received from server: ['69', '4', '9', '820.0', '61']
# Generated RMM array for row: [68, 5, 3, 822.39, 129]
# Generated HMM array for row: [68, 4, 9, 820.0, 37]
# Raw data received from server: ['70', '3', '9', '840.0', '79']
# Generated RMM array for row: [69, 3, 3, 838.7, 148]
# Generated HMM array for row: [69, 3, 9, 840.0, 37]
# Raw data received from server: ['71', '2', '9', '850.0', '82']
# Generated RMM array for row: [70, 1, 3, 844.19, 152]
# Generated HMM array for row: [70, 2, 9, 850.0, 37]
# Raw data received from server: ['72', '1', '9', '860.0', '85']
# Generated RMM array for row: [71, 1, 3, 862.12, 156]
# Generated HMM array for row: [71, 1, 9, 860.0, 37]
# Raw data received from server: ['73', '0', '9', '870.0', '88']
# Generated RMM array for row: [72, 1, 3, 869.92, 160]
# Generated HMM array for row: [72, 0, 9, 870.0, 37]
# Raw data received from server: ['74', '0', '8', '880.0', '87']
# Generated RMM array for row: [73, 1, 3, 879.07, 160]
# Generated HMM array for row: [73, 0, 8, 880.0, 37]
# Raw data received from server: ['75', '0', '7', '890.0', '86']
# Generated RMM array for row: [74, 1, 3, 890.51, 160]
# Generated HMM array for row: [74, 0, 7, 890.0, 37]
# Raw data received from server: ['76', '0', '6', '900.0', '85']
# Generated RMM array for row: [75, 1, 3, 899.9, 160]
# Generated HMM array for row: [75, 0, 6, 900.0, 37]
# Raw data received from server: ['77', '0', '5', '910.0', '84']
# Generated RMM array for row: [76, 1, 3, 908.73, 160]
# Generated HMM array for row: [76, 0, 5, 910.0, 37]
# Raw data received from server: ['78', '0', '6', '920.0', '87']
# Generated RMM array for row: [77, 1, 3, 921.81, 164]
# Generated HMM array for row: [77, 0, 6, 920.0, 37]
# Raw data received from server: ['79', '0', '7', '930.0', '90']
# Generated RMM array for row: [78, 1, 3, 924.61, 168]
# Generated HMM array for row: [78, 0, 7, 930.0, 37]
# Raw data received from server: ['80', '0', '8', '940.0', '93']
# Generated RMM array for row: [79, 0, 3, 937.05, 172]
# Generated HMM array for row: [79, 0, 8, 940.0, 37]
# Raw data received from server: ['81', '1', '8', '990.0', '90']
# Generated RMM array for row: [80, 0, 3, 987.98, 170]
# Generated HMM array for row: [80, 1, 8, 990.0, 37]
# Raw data received from server: ['82', '1', '7', '1000.0', '89']
# Generated RMM array for row: [81, 1, 3, 1001.92, 170]
# Generated HMM array for row: [81, 1, 7, 1000.0, 37]
# Raw data received from server: ['83', '1', '6', '1010.0', '88']
# Generated RMM array for row: [82, 2, 3, 1008.27, 170]
# Generated HMM array for row: [82, 1, 6, 1010.0, 37]
# Raw data received from server: ['84', '1', '5', '1020.0', '87']
# Generated RMM array for row: [83, 1, 3, 1021.09, 170]
# Generated HMM array for row: [83, 1, 5, 1020.0, 37]
# Raw data received from server: ['85', '2', '5', '1030.0', '86']
# Generated RMM array for row: [84, 3, 3, 1031.81, 170]
# Generated HMM array for row: [84, 2, 5, 1030.0, 37]
# Raw data received from server: ['86', '3', '5', '1040.0', '85']
# Generated RMM array for row: [85, 5, 3, 1042.86, 170]
# Generated HMM array for row: [85, 3, 5, 1040.0, 37]
# Raw data received from server: ['87', '4', '5', '1050.0', '84']
# Generated RMM array for row: [86, 5, 3, 1046.08, 170]
# Generated HMM array for row: [86, 4, 5, 1050.0, 37]
# Raw data received from server: ['88', '3', '5', '1060.0', '83']
# Generated RMM array for row: [87, 2, 3, 1061.13, 170]
# Generated HMM array for row: [87, 3, 5, 1060.0, 37]
# Raw data received from server: ['89', '2', '5', '1070.0', '82']
# Generated RMM array for row: [88, 3, 3, 1070.5, 170]
# Generated HMM array for row: [88, 2, 5, 1070.0, 37]
# Raw data received from server: ['90', '1', '5', '1080.0', '81']
# Generated RMM array for row: [89, 1, 3, 1087.01, 170]
# Generated HMM array for row: [89, 1, 5, 1080.0, 37]
# Raw data received from server: ['91', '1', '6', '1090.0', '80']
# Generated RMM array for row: [90, 2, 3, 1086.46, 170]
# Generated HMM array for row: [90, 1, 6, 1090.0, 37]
# Raw data received from server: ['92', '1', '7', '1100.0', '79']
# Generated RMM array for row: [91, 0, 3, 1099.18, 170]
# Generated HMM array for row: [91, 1, 7, 1100.0, 37]
# Raw data received from server: ['93', '1', '8', '1110.0', '78']
# Generated RMM array for row: [92, 0, 3, 1112.27, 170]
# Generated HMM array for row: [92, 1, 8, 1110.0, 37]
# Raw data received from server: ['94', '0', '8', '1120.0', '77']
# Generated RMM array for row: [93, 2, 3, 1120.81, 170]
# Generated HMM array for row: [93, 0, 8, 1120.0, 37]
# Raw data received from server: ['95', '0', '7', '1130.0', '76']
# Generated RMM array for row: [94, 0, 3, 1127.56, 170]
# Generated HMM array for row: [94, 0, 7, 1130.0, 37]
# Raw data received from server: ['96', '0', '6', '1140.0', '75']
# Generated RMM array for row: [95, 0, 3, 1134.44, 170]
# Generated HMM array for row: [95, 0, 6, 1140.0, 37]
# Raw data received from server: ['97', '0', '5', '1150.0', '74']
# Generated RMM array for row: [96, 1, 3, 1148.72, 170]
# Generated HMM array for row: [96, 0, 5, 1150.0, 37]
# Raw data received from server: ['98', '0', '4', '1160.0', '73']
# Generated RMM array for row: [97, 2, 3, 1165.37, 170]
# Generated HMM array for row: [97, 0, 4, 1160.0, 37]
# Raw data received from server: ['99', '0', '3', '1180.0', '114']
# Generated RMM array for row: [98, 1, 3, 1177.24, 212]
# Generated HMM array for row: [98, 0, 3, 1180.0, 37]
# Raw data received from server: ['100', '0', '2', '1190.0', '117']
# Generated RMM array for row: [99, 0, 2, 1188.88, 216]
# Generated HMM array for row: [99, 0, 2, 1190.0, 37]
# Raw data received from server: ['101', '0', '1', '1200.0', '116']
# Generated RMM array for row: [100, 1, 1, 1199.08, 216]
# Generated HMM array for row: [100, 0, 1, 1200.0, 37]
# Raw data received from server: ['102', '1', '1', '1250.0', '115']
# Generated RMM array for row: [101, 3, 1, 1250.58, 216]
# Generated HMM array for row: [101, 1, 1, 1250.0, 37]
# Raw data received from server: ['103', '1', '2', '1260.0', '114']
# Generated RMM array for row: [102, 1, 2, 1257.27, 216]
# Generated HMM array for row: [102, 1, 2, 1260.0, 37]
# Raw data received from server: ['104', '1', '3', '1270.0', '113']
# Generated RMM array for row: [103, 1, 3, 1265.47, 216]
# Generated HMM array for row: [103, 1, 3, 1270.0, 37]
# Raw data received from server: ['105', '1', '4', '1280.0', '112']
# Generated RMM array for row: [104, 3, 3, 1280.61, 216]
# Generated HMM array for row: [104, 1, 4, 1280.0, 37]
# Raw data received from server: ['106', '2', '4', '1290.0', '111']
# Generated RMM array for row: [105, 1, 3, 1291.74, 216]
# Generated HMM array for row: [105, 2, 4, 1290.0, 37]
# Raw data received from server: ['107', '3', '4', '1300.0', '110']
# Generated RMM array for row: [106, 4, 3, 1299.26, 216]
# Generated HMM array for row: [106, 3, 4, 1300.0, 37]
# Raw data received from server: ['108', '4', '4', '1310.0', '109']
# Generated RMM array for row: [107, 4, 3, 1313.14, 216]
# Generated HMM array for row: [107, 4, 4, 1310.0, 37]
# Raw data received from server: ['109', '3', '4', '1320.0', '108']
# Generated RMM array for row: [108, 2, 3, 1320.41, 216]
# Generated HMM array for row: [108, 3, 4, 1320.0, 37]
# Raw data received from server: ['110', '2', '4', '1330.0', '107']
# Generated RMM array for row: [109, 3, 3, 1328.3, 216]
# Generated HMM array for row: [109, 2, 4, 1330.0, 37]
# Raw data received from server: ['111', '1', '4', '1340.0', '106']
# Generated RMM array for row: [110, 2, 3, 1340.36, 216]
# Generated HMM array for row: [110, 1, 4, 1340.0, 37]
# Raw data received from server: ['112', '1', '3', '1350.0', '105']
# Generated RMM array for row: [111, 0, 3, 1348.76, 216]
# Generated HMM array for row: [111, 1, 3, 1350.0, 37]
# Raw data received from server: ['113', '1', '2', '1360.0', '104']
# Generated RMM array for row: [112, 0, 2, 1357.83, 216]
# Generated HMM array for row: [112, 1, 2, 1360.0, 37]
# Raw data received from server: ['114', '1', '1', '1370.0', '103']
# Generated RMM array for row: [113, 0, 1, 1366.94, 216]
# Generated HMM array for row: [113, 1, 1, 1370.0, 37]
# Raw data received from server: ['115', '1', '0', '1420.0', '102']
# Generated RMM array for row: [114, 1, 0, 1417.99, 216]
# Generated HMM array for row: [114, 1, 0, 1420.0, 37]
# Raw data received from server: ['116', '2', '0', '1430.0', '101']
# Generated RMM array for row: [115, 2, 0, 1429.92, 216]
# Generated HMM array for row: [115, 2, 0, 1430.0, 37]
# Raw data received from server: ['117', '3', '0', '1440.0', '100']
# Generated RMM array for row: [116, 3, 0, 1439.77, 216]
# Generated HMM array for row: [116, 3, 0, 1440.0, 37]
# Raw data received from server: ['118', '4', '0', '1450.0', '99']
# Generated RMM array for row: [117, 5, 0, 1451.0, 216]
# Generated HMM array for row: [117, 4, 0, 1450.0, 37]
# Raw data received from server: ['119', '5', '0', '1460.0', '98']
# Generated RMM array for row: [118, 3, 0, 1462.45, 216]
# Generated HMM array for row: [118, 5, 0, 1460.0, 37]
# Raw data received from server: ['120', '6', '0', '1470.0', '97']
# Generated RMM array for row: [119, 5, 0, 1466.36, 216]
# Generated HMM array for row: [119, 6, 0, 1470.0, 37]
# Raw data received from server: ['121', '7', '0', '1480.0', '96']
# Generated RMM array for row: [120, 5, 0, 1478.41, 216]
# Generated HMM array for row: [120, 7, 0, 1480.0, 37]
# Raw data received from server: ['122', '8', '0', '1490.0', '95']
# Generated RMM array for row: [121, 5, 0, 1492.3, 216]
# Generated HMM array for row: [121, 8, 0, 1490.0, 37]
# Raw data received from server: ['123', '8', '1', '1540.0', '94']
# Generated RMM array for row: [122, 5, 1, 1540.82, 216]
# Generated HMM array for row: [122, 8, 1, 1540.0, 37]
# Raw data received from server: ['124', '7', '1', '1550.0', '93']
# Generated RMM array for row: [123, 5, 1, 1548.1, 216]
# Generated HMM array for row: [123, 7, 1, 1550.0, 37]
# Raw data received from server: ['125', '6', '1', '1560.0', '92']
# Generated RMM array for row: [124, 5, 1, 1558.52, 216]
# Generated HMM array for row: [124, 6, 1, 1560.0, 37]
# Raw data received from server: ['126', '5', '1', '1570.0', '91']
# Generated RMM array for row: [125, 5, 1, 1569.9, 216]
# Generated HMM array for row: [125, 5, 1, 1570.0, 37]
# Raw data received from server: ['127', '5', '2', '1580.0', '90']
# Generated RMM array for row: [126, 5, 2, 1577.29, 216]
# Generated HMM array for row: [126, 5, 2, 1580.0, 37]
# Raw data received from server: ['128', '5', '3', '1590.0', '89']
# Generated RMM array for row: [127, 4, 3, 1590.67, 216]
# Generated HMM array for row: [127, 5, 3, 1590.0, 37]
# Raw data received from server: ['129', '5', '4', '1600.0', '88']
# Generated RMM array for row: [128, 5, 3, 1602.28, 216]
# Generated HMM array for row: [128, 5, 4, 1600.0, 37]
# Raw data received from server: ['130', '5', '3', '1610.0', '87']
# Generated RMM array for row: [129, 4, 3, 1607.99, 216]
# Generated HMM array for row: [129, 5, 3, 1610.0, 37]
# Raw data received from server: ['131', '5', '2', '1620.0', '86']
# Generated RMM array for row: [130, 5, 2, 1621.61, 216]
# Generated HMM array for row: [130, 5, 2, 1620.0, 37]
# Raw data received from server: ['132', '5', '1', '1630.0', '85']
# Generated RMM array for row: [131, 5, 1, 1630.46, 216]
# Generated HMM array for row: [131, 5, 1, 1630.0, 37]
# Raw data received from server: ['133', '6', '1', '1640.0', '84']
# Generated RMM array for row: [132, 5, 1, 1640.86, 216]
# Generated HMM array for row: [132, 6, 1, 1640.0, 37]
# Raw data received from server: ['134', '7', '1', '1650.0', '83']
# Generated RMM array for row: [133, 5, 1, 1645.84, 216]
# Generated HMM array for row: [133, 7, 1, 1650.0, 37]
# Raw data received from server: ['135', '8', '1', '1660.0', '82']
# Generated RMM array for row: [134, 5, 1, 1665.39, 216]
# Generated HMM array for row: [134, 8, 1, 1660.0, 37]
# Raw data received from server: ['136', '9', '1', '1670.0', '81']
# Generated RMM array for row: [135, 5, 1, 1669.91, 216]
# Generated HMM array for row: [135, 9, 1, 1670.0, 37]
# Raw data received from server: ['137', '9', '2', '1680.0', '80']
# Generated RMM array for row: [136, 5, 2, 1678.81, 216]
# Generated HMM array for row: [136, 9, 2, 1680.0, 37]
# Raw data received from server: ['138', '9', '3', '1690.0', '79']
# Generated RMM array for row: [137, 5, 3, 1689.94, 216]
# Generated HMM array for row: [137, 9, 3, 1690.0, 37]
# Raw data received from server: ['139', '9', '4', '1700.0', '78']
# Generated RMM array for row: [138, 5, 3, 1700.01, 216]
# Generated HMM array for row: [138, 9, 4, 1700.0, 37]
# Raw data received from server: ['140', '9', '5', '1710.0', '77']
# Generated RMM array for row: [139, 5, 3, 1711.07, 216]
# Generated HMM array for row: [139, 9, 5, 1710.0, 37]
# Raw data received from server: ['141', '9', '6', '1720.0', '76']
# Generated RMM array for row: [140, 5, 3, 1725.52, 216]
# Generated HMM array for row: [140, 9, 6, 1720.0, 37]
# Raw data received from server: ['142', '9', '7', '1730.0', '75']
# Generated RMM array for row: [141, 5, 3, 1728.08, 216]
# Generated HMM array for row: [141, 9, 7, 1730.0, 37]
# Raw data received from server: ['143', '9', '8', '1740.0', '74']
# Generated RMM array for row: [142, 5, 3, 1737.49, 216]
# Generated HMM array for row: [142, 9, 8, 1740.0, 37]
# Raw data received from server: ['144', '8', '8', '1750.0', '73']
# Generated RMM array for row: [143, 5, 3, 1754.27, 216]
# Generated HMM array for row: [143, 8, 8, 1750.0, 37]
# Raw data received from server: ['145', '7', '8', '1760.0', '72']
# Generated RMM array for row: [144, 5, 3, 1761.03, 216]
# Generated HMM array for row: [144, 7, 8, 1760.0, 37]
# Raw data received from server: ['146', '6', '8', '1770.0', '71']
# Generated RMM array for row: [145, 5, 3, 1768.25, 216]
# Generated HMM array for row: [145, 6, 8, 1770.0, 37]
# Raw data received from server: ['147', '5', '8', '1780.0', '70']
# Generated RMM array for row: [146, 4, 3, 1784.16, 216]
# Generated HMM array for row: [146, 5, 8, 1780.0, 37]
# Raw data received from server: ['148', '5', '7', '1790.0', '69']
# Generated RMM array for row: [147, 5, 3, 1789.15, 216]
# Generated HMM array for row: [147, 5, 7, 1790.0, 37]
# Raw data received from server: ['149', '5', '6', '1800.0', '68']
# Generated RMM array for row: [148, 5, 3, 1795.33, 216]
# Generated HMM array for row: [148, 5, 6, 1800.0, 37]
# Raw data received from server: ['150', '5', '5', '1810.0', '67']
# Generated RMM array for row: [149, 5, 3, 1811.59, 216]
# Generated HMM array for row: [149, 5, 5, 1810.0, 37]
# Raw data received from server: ['151', '5', '6', '1820.0', '66']
# Generated RMM array for row: [150, 4, 3, 1819.89, 216]
# Generated HMM array for row: [150, 5, 6, 1820.0, 37]
# Raw data received from server: ['152', '5', '7', '1830.0', '65']
# Generated RMM array for row: [151, 5, 3, 1825.47, 216]
# Generated HMM array for row: [151, 5, 7, 1830.0, 37]
# Raw data received from server: ['153', '5', '8', '1840.0', '64']
# Generated RMM array for row: [152, 5, 3, 1841.16, 216]
# Generated HMM array for row: [152, 5, 8, 1840.0, 37]
# Raw data received from server: ['154', '6', '8', '1850.0', '63']
# Generated RMM array for row: [153, 5, 3, 1853.22, 216]
# Generated HMM array for row: [153, 6, 8, 1850.0, 37]
# Raw data received from server: ['155', '7', '8', '1860.0', '62']
# Generated RMM array for row: [154, 5, 3, 1861.35, 216]
# Generated HMM array for row: [154, 7, 8, 1860.0, 37]
# Raw data received from server: ['156', '8', '8', '1870.0', '61']
# Generated RMM array for row: [155, 5, 3, 1872.95, 216]
# Generated HMM array for row: [155, 8, 8, 1870.0, 37]
# Raw data received from server: ['157', '8', '9', '1880.0', '60']
# Generated RMM array for row: [156, 5, 3, 1877.61, 216]
# Generated HMM array for row: [156, 8, 9, 1880.0, 37]
# Raw data received from server: ['158', '7', '9', '1890.0', '59']
# Generated RMM array for row: [157, 5, 3, 1886.5, 216]
# Generated HMM array for row: [157, 7, 9, 1890.0, 37]
# Raw data received from server: ['159', '6', '9', '1900.0', '58']
# Generated RMM array for row: [158, 5, 3, 1900.16, 216]
# Generated HMM array for row: [158, 6, 9, 1900.0, 37]
# Raw data received from server: ['160', '5', '9', '1910.0', '57']
# Generated RMM array for row: [159, 4, 3, 1911.15, 216]
# Generated HMM array for row: [159, 5, 9, 1910.0, 37]
# Raw data received from server: ['161', '4', '9', '1920.0', '56']
# Generated RMM array for row: [160, 4, 3, 1922.13, 216]
# Generated HMM array for row: [160, 4, 9, 1920.0, 37]
# Raw data received from server: ['162', '3', '9', '1930.0', '55']
# Generated RMM array for row: [161, 4, 3, 1928.89, 216]
# Generated HMM array for row: [161, 3, 9, 1930.0, 37]
# Raw data received from server: ['163', '2', '9', '1940.0', '54']
# Generated RMM array for row: [162, 3, 3, 1942.39, 216]
# Generated HMM array for row: [162, 2, 9, 1940.0, 37]
# Raw data received from server: ['164', '1', '9', '1950.0', '53']
# Generated RMM array for row: [163, 1, 3, 1947.27, 216]
# Generated HMM array for row: [163, 1, 9, 1950.0, 37]
# Raw data received from server: ['165', '1', '8', '1960.0', '52']
# Generated RMM array for row: [164, 3, 3, 1957.85, 216]
# Generated HMM array for row: [164, 1, 8, 1960.0, 37]
# Raw data received from server: ['166', '1', '7', '1970.0', '51']
# Generated RMM array for row: [165, 2, 3, 1968.38, 216]
# Generated HMM array for row: [165, 1, 7, 1970.0, 37]
# Raw data received from server: ['167', '1', '6', '1980.0', '50']
# Generated RMM array for row: [166, 0, 3, 1981.58, 216]
# Generated HMM array for row: [166, 1, 6, 1980.0, 37]
# Raw data received from server: ['168', '1', '5', '1990.0', '49']
# Generated RMM array for row: [167, 1, 3, 1985.71, 216]
# Generated HMM array for row: [167, 1, 5, 1990.0, 37]
# Raw data received from server: ['169', '2', '5', '2000.0', '48']
# Generated RMM array for row: [168, 3, 3, 1996.12, 216]
# Generated HMM array for row: [168, 2, 5, 2000.0, 37]
# Raw data received from server: ['170', '3', '5', '2010.0', '47']
# Generated RMM array for row: [169, 3, 3, 2002.87, 216]
# Generated HMM array for row: [169, 3, 5, 2010.0, 37]
# Raw data received from server: ['171', '4', '5', '2020.0', '46']
# Generated RMM array for row: [170, 3, 3, 2021.96, 216]
# Generated HMM array for row: [170, 4, 5, 2020.0, 37]
# Raw data received from server: ['172', '3', '5', '2030.0', '45']
# Generated RMM array for row: [171, 4, 3, 2029.52, 216]
# Generated HMM array for row: [171, 3, 5, 2030.0, 37]
# Raw data received from server: ['173', '2', '5', '2040.0', '44']
# Generated RMM array for row: [172, 2, 3, 2039.83, 216]
# Generated HMM array for row: [172, 2, 5, 2040.0, 37]
# Raw data received from server: ['174', '1', '5', '2050.0', '43']
# Generated RMM array for row: [173, 0, 3, 2051.66, 216]
# Generated HMM array for row: [173, 1, 5, 2050.0, 37]
# Raw data received from server: ['175', '1', '6', '2060.0', '42']
# Generated RMM array for row: [174, 0, 3, 2067.24, 216]
# Generated HMM array for row: [174, 1, 6, 2060.0, 37]
# Raw data received from server: ['176', '1', '7', '2070.0', '41']
# Generated RMM array for row: [175, 1, 3, 2075.46, 216]
# Generated HMM array for row: [175, 1, 7, 2070.0, 37]
# Raw data received from server: ['177', '1', '8', '2080.0', '40']
# Generated RMM array for row: [176, 0, 3, 2083.41, 216]
# Generated HMM array for row: [176, 1, 8, 2080.0, 37]
# Raw data received from server: ['178', '0', '8', '2090.0', '39']
# Generated RMM array for row: [177, 0, 3, 2094.38, 216]
# Generated HMM array for row: [177, 0, 8, 2090.0, 37]
# Raw data received from server: ['179', '0', '7', '2100.0', '38']
# Generated RMM array for row: [178, 2, 3, 2098.85, 216]
# Generated HMM array for row: [178, 0, 7, 2100.0, 37]
# Raw data received from server: ['180', '0', '6', '2110.0', '37']
# Generated RMM array for row: [179, 1, 3, 2110.81, 216]
# Generated HMM array for row: [179, 0, 6, 2110.0, 37]
# Raw data received from server: ['181', '0', '5', '2120.0', '36']
# Generated RMM array for row: [180, 0, 3, 2123.26, 216]
# Generated HMM array for row: [180, 0, 5, 2120.0, 37]
# Raw data received from server: ['182', '0', '4', '2130.0', '35']
# Generated RMM array for row: [181, 1, 3, 2130.68, 216]
# Generated HMM array for row: [181, 0, 4, 2130.0, 37]
# Raw data received from server: ['183', '0', '3', '2140.0', '34']
# Generated RMM array for row: [182, 1, 3, 2143.38, 216]
# Generated HMM array for row: [182, 0, 3, 2140.0, 37]
# Raw data received from server: ['184', '0', '2', '2150.0', '33']
# Generated RMM array for row: [183, 0, 2, 2151.0, 216]
# Generated HMM array for row: [183, 0, 2, 2150.0, 37]
# Raw data received from server: ['185', '0', '1', '2160.0', '32']
# Generated RMM array for row: [184, 2, 1, 2156.98, 216]
# Generated HMM array for row: [184, 0, 1, 2160.0, 37]
# Raw data received from server: ['186', '1', '1', '2170.0', '31']
# Generated RMM array for row: [185, 1, 1, 2174.95, 216]
# Generated HMM array for row: [185, 1, 1, 2170.0, 37]
# Raw data received from server: ['187', '1', '2', '2180.0', '30']
# Generated RMM array for row: [186, 1, 2, 2182.32, 216]
# Generated HMM array for row: [186, 1, 2, 2180.0, 37]
# Raw data received from server: ['188', '1', '3', '2190.0', '29']
# Generated RMM array for row: [187, 1, 3, 2186.32, 216]
# Generated HMM array for row: [187, 1, 3, 2190.0, 37]
# Raw data received from server: ['189', '1', '4', '2200.0', '28']
# Generated RMM array for row: [188, 1, 3, 2200.74, 216]
# Generated HMM array for row: [188, 1, 4, 2200.0, 37]
# Raw data received from server: ['190', '2', '4', '2210.0', '27']
# Generated RMM array for row: [189, 2, 3, 2209.07, 216]
# Generated HMM array for row: [189, 2, 4, 2210.0, 37]
# Raw data received from server: ['191', '3', '4', '2220.0', '26']
# Generated RMM array for row: [190, 2, 3, 2223.85, 216]
# Generated HMM array for row: [190, 3, 4, 2220.0, 37]
# Raw data received from server: ['192', '4', '4', '2230.0', '25']
# Generated RMM array for row: [191, 4, 3, 2227.87, 216]
# Generated HMM array for row: [191, 4, 4, 2230.0, 37]
# Raw data received from server: ['193', '3', '4', '2240.0', '24']
# Generated RMM array for row: [192, 2, 3, 2242.43, 216]
# Generated HMM array for row: [192, 3, 4, 2240.0, 37]
# Raw data received from server: ['194', '2', '4', '2250.0', '23']
# Generated RMM array for row: [193, 1, 3, 2254.74, 216]
# Generated HMM array for row: [193, 2, 4, 2250.0, 37]
# Raw data received from server: ['195', '1', '4', '2260.0', '22']
# Generated RMM array for row: [194, 1, 3, 2261.27, 216]
# Generated HMM array for row: [194, 1, 4, 2260.0, 37]
# Raw data received from server: ['196', '1', '3', '2270.0', '21']
# Generated RMM array for row: [195, 2, 3, 2272.55, 216]
# Generated HMM array for row: [195, 1, 3, 2270.0, 37]
# Raw data received from server: ['197', '1', '2', '2280.0', '20']
# Generated RMM array for row: [196, 2, 2, 2281.27, 216]
# Generated HMM array for row: [196, 1, 2, 2280.0, 37]
# Raw data received from server: ['198', '1', '1', '2290.0', '19']
# Generated RMM array for row: [197, 1, 1, 2290.2, 216]
# Generated HMM array for row: [197, 1, 1, 2290.0, 37]
# Raw data received from server: ['199', '1', '0', '2300.0', '18']
# Generated RMM array for row: [198, 1, 0, 2302.23, 216]
# Generated HMM array for row: [198, 1, 0, 2300.0, 37]
# Raw data received from server: ['200', '2', '0', '2310.0', '17']
# Generated RMM array for row: [199, 3, 0, 2307.41, 216]
# Generated HMM array for row: [199, 2, 0, 2310.0, 37]
# Raw data received from server: ['201', '3', '0', '2320.0', '16']
# Generated RMM array for row: [200, 2, 0, 2328.5, 216]
# Generated HMM array for row: [200, 3, 0, 2320.0, 37]
# Raw data received from server: ['202', '4', '0', '2330.0', '15']
# Generated RMM array for row: [201, 5, 0, 2331.52, 216]
# Generated HMM array for row: [201, 4, 0, 2330.0, 37]
# Raw data received from server: ['203', '5', '0', '2340.0', '14']
# Generated RMM array for row: [202, 5, 0, 2343.8, 216]
# Generated HMM array for row: [202, 5, 0, 2340.0, 37]
# Raw data received from server: ['204', '6', '0', '2350.0', '13']
# Generated RMM array for row: [203, 5, 0, 2349.11, 216]
# Generated HMM array for row: [203, 6, 0, 2350.0, 37]
# Raw data received from server: ['205', '7', '0', '2360.0', '12']
# Generated RMM array for row: [204, 5, 0, 2365.32, 216]
# Generated HMM array for row: [204, 7, 0, 2360.0, 37]
# Raw data received from server: ['206', '8', '0', '2370.0', '11']
# Generated RMM array for row: [205, 5, 0, 2370.02, 216]
# Generated HMM array for row: [205, 8, 0, 2370.0, 37]
# Raw data received from server: ['207', '8', '1', '2380.0', '10']
# Generated RMM array for row: [206, 5, 1, 2385.29, 216]
# Generated HMM array for row: [206, 8, 1, 2380.0, 37]
# Raw data received from server: ['208', '7', '1', '2390.0', '9']
# Generated RMM array for row: [207, 5, 1, 2391.24, 216]
# Generated HMM array for row: [207, 7, 1, 2390.0, 37]
# Raw data received from server: ['209', '6', '1', '2400.0', '8']
# Generated RMM array for row: [208, 5, 1, 2396.9, 216]
# Generated HMM array for row: [208, 6, 1, 2400.0, 37]
# Raw data received from server: ['210', '5', '1', '2410.0', '7']
# Generated RMM array for row: [209, 5, 1, 2409.78, 216]
# Generated HMM array for row: [209, 5, 1, 2410.0, 37]
# Raw data received from server: ['211', '5', '2', '2420.0', '6']
# Generated RMM array for row: [210, 5, 2, 2423.64, 216]
# Generated HMM array for row: [210, 5, 2, 2420.0, 37]
# Raw data received from server: ['212', '5', '3', '2430.0', '5']
# Generated RMM array for row: [211, 5, 3, 2429.77, 216]
# Generated HMM array for row: [211, 5, 3, 2430.0, 37]
# Raw data received from server: ['213', '5', '4', '2440.0', '4']
# Generated RMM array for row: [212, 4, 3, 2444.23, 216]
# Generated HMM array for row: [212, 5, 4, 2440.0, 37]
# Raw data received from server: ['214', '5', '3', '2450.0', '3']
# Generated RMM array for row: [213, 5, 3, 2448.12, 216]
# Generated HMM array for row: [213, 5, 3, 2450.0, 37]
# Raw data received from server: ['215', '5', '3', '2450.0', '2']
# Generated RMM array for row: [214, 5, 3, 2447.78, 216]
# Generated HMM array for row: [214, 5, 3, 2450.0, 37]
# Raw data received from server: ['216', '5', '2', '2460.0', '1']
# Generated RMM array for row: [215, 5, 2, 2457.39, 216]
# Generated HMM array for row: [215, 5, 2, 2460.0, 37]
# Raw data received from server: ['217', '5', '1', '2470.0', '0']
# Generated RMM array for row: [216, 4, 1, 2470.88, 216]
# Generated HMM array for row: [216, 5, 1, 2470.0, 37]
# Connection closed. Stopping client.

# %%
def generate_rmm_array(shmm_data):
    num_tasks = len(shmm_data)

    position_values = [pose[0] for pose in shmm_data]
    time_values = [pose[1] for pose in shmm_data]
    mission_tim_values = [pose[2] for pose in shmm_data]

    # Increase noise standard deviation
    position_noise = np.random.normal(0, 1, num_tasks)  # Adjusted standard deviation
    time_noise = np.random.normal(0, 3, num_tasks)

    rmm_array = []
    prev_time = 0  # Variable to track the previous time value

    for i in range(num_tasks):
        position_value1 = int(np.round(np.abs(position_values[i][0] + position_noise[i])))
        position_value2 = int(np.round(np.abs(position_values[i][1] + np.random.normal(0, 0.1))))
        time_taken = round((np.abs(time_values[i] + time_noise[i])),2)
        mission_tim = int(mission_tim_values[i])

        # Clip position values to be within specified limits
        position_value1 = np.clip(position_value1, 0, 5)
        position_value2 = np.clip(position_value2, 0, 3)

        rmm_array.append([i, position_value1, position_value2, time_taken, mission_tim])

        # Update the previous time value
        prev_time = time_taken + 1  # Increase time for the next iteration

    return rmm_array



# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    norm = (np.array(array2) - np.array(array1))
    return norm


def bayesian_probabilistic_update_general(original_value, deviation, threshold, uncertainty_factor):
    # Expectation step: compute the expected value of the latent variable
    expected_value = original_value + deviation

    # Maximization step: update the parameter using the expected value
    updated_value = expected_value

    # Update only if the deviation crosses the threshold
    updated_value = updated_value if abs(deviation) > threshold else original_value
    return updated_value


# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        message_template = (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            f"**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        message_template = (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "low_battery":
        message_template = (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "communication_failure":
        message_template = (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            f"**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        message_template = (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            f"**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message_template = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"

        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds. \n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds. \n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule. \n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'}" \
                               f" from the expected position ({A})."

        message_template += time_message + position_message + "\n\n" + "-" * 50

    return message_template


def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Assuming robot number 1 for example
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        # print(delay_message)
        messages.append(delay_message)  # Append formatted delay message to messages list
        # print(messages)
    return messages



def dynamic_deviation_threshold_multi_logic(hmm_arrays, rmm_arrays, update_logic_functions, uncertainty_factor_pos, uncertainty_factor_time):
    all_updated_hmm_arrays = []
    all_communication_messages = []  # Initialize list to collect all communication messages

    for i, update_logic in enumerate(update_logic_functions):

        mission_time_deviation = calculate_l1_norm([hmm_arrays[i][4]], [rmm_arrays[i][4]])[0]


        # dynamic_threshold_mission_time = 10 # 11 stars # dataset low threshold high sensitivity 3
        # dynamic_threshold_mission_time = 15 # 8 stars # dataset medium 2
        dynamic_threshold_mission_time = 20 # 6 stars # dataset high threshold low sensitivity 1


        # dynamic_threshold_mission_time = 40 # 8 stars # 20 datasize jiming


        updated_hmm_array = []
        communication_messages = []  # Initialize list to collect communication messages for this logic iteration

        current_hmm_mission_time = rmm_arrays[0][4]

        for j in range(len(hmm_arrays)):
            updated_pos1 = rmm_arrays[j][1]
            updated_pos2 = rmm_arrays[j][2]
            mission_time_deviation = calculate_l1_norm([current_hmm_mission_time], [rmm_arrays[j][4]])[0]

            hmm_pos1 = hmm_arrays[j][1]
            hmm_pos2 = hmm_arrays[j][2]
            rmm_pos1 = rmm_arrays[j][1]
            rmm_pos2 = rmm_arrays[j][2]
            hmm_time = hmm_arrays[j][3]
            rmm_time = rmm_arrays[j][3]

            messages = generate_communication_message(mission_time_deviation, dynamic_threshold_mission_time,
                                                     hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time)
            communication_messages.extend(messages)

            updated_mission_time = update_logic(current_hmm_mission_time, mission_time_deviation,
                                               dynamic_threshold_mission_time, uncertainty_factor_time)
            current_hmm_mission_time = updated_mission_time

            updated_hmm_array.append([j, int(round(updated_pos1, 0)), int(round(updated_pos2, 0)), None, updated_mission_time])

        all_updated_hmm_arrays.append(np.array(updated_hmm_array))  # Append updated hmm_array to list
        all_communication_messages.append(communication_messages)  # Append communication messages to list for this logic

    return all_updated_hmm_arrays, all_communication_messages  # Return both arrays and messages

def save_to_csv(filename, data):
    with open(filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerows(data)



if __name__ == "__main__":
    update_logics = [bayesian_probabilistic_update_general]

    uncertainty_factor_pos = 0.05
    uncertainty_factor_time = 0.01

    shmm_data = []

    # Read data from CSV file and format it
    # with open("robot_data_20_jiming.csv", 'r') as csvfile:
    with open("robot_data_10_jiming.csv", 'r') as csvfile:
        csv_reader = csv.reader(csvfile, delimiter='\t')
        timestep = 0
        for row in csv_reader:
            first_state = int(row[1])
            second_state = int(row[2])
            time_elapsed = float(row[3])
            steps_remaining = int(row[4])
            mission_time = timestep + steps_remaining
            shmm_data.append(((first_state, second_state), time_elapsed, mission_time))
            timestep += 1

    rmm_arrays = generate_rmm_array(shmm_data)
    shmm_data_with_index = [[i, pose[0][0], pose[0][1], pose[1], pose[2]] for i, pose in enumerate(shmm_data)]
    hmm_arrays = [[arr[0], arr[1], arr[2], round(arr[3], 2), 37] for arr in shmm_data_with_index]

    all_updated_arrays, communication_details = dynamic_deviation_threshold_multi_logic(
        hmm_arrays, rmm_arrays, update_logics, uncertainty_factor_pos, uncertainty_factor_time
    )

# %%
import asyncio
import websockets

async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        while True:
            # Receive one row of data from the server
            data_from_server = await websocket.recv()
            
            # Print the raw data received from the server
            print(f"Raw data received from server: {data_from_server}")
            
            # Parse the received data (convert string to list)
            row = eval(data_from_server)  # Convert string back to list
            
            # Extract data from the row
            first_state = int(row[1])
            second_state = int(row[2])
            steps_remaining = int(row[4])
            mission_time = timestep + steps_remaining  # timestep + steps_remaining
            
            # Append the processed data to SHMM-like structure
            # (No need for time_elapsed, only mission_time based on timestep)
            shmm_data = [[timestep, first_state, second_state, steps_remaining, mission_time]]
            
            # Convert the processed data into the hmm_array format
            hmm_array = [timestep, first_state, second_state, round(float(row[3]), 2), 37]  # 37 as a constant value
            
            # Print the converted hmm_array
            print(f"Converted to hmm_array: {hmm_array}")
            
            # Send a confirmation message back to the server
            await websocket.send("Data received and processed")
            
            # Increment timestep for next data point
            timestep += 1
            
            # Introduce delay to simulate processing time
            await asyncio.sleep(1)

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Converted to hmm_array: [0, 4, 3, 10.0, 37]
# Raw data received from server: ['2', '4', '2', '20.0', '47']
# Converted to hmm_array: [1, 4, 2, 20.0, 37]
# Raw data received from server: ['3', '4', '1', '30.0', '46']
# Converted to hmm_array: [2, 4, 1, 30.0, 37]
# Raw data received from server: ['4', '3', '1', '40.0', '49']
# Converted to hmm_array: [3, 3, 1, 40.0, 37]
# Raw data received from server: ['5', '2', '1', '50.0', '52']
# Converted to hmm_array: [4, 2, 1, 50.0, 37]
# Raw data received from server: ['6', '1', '1', '60.0', '55']
# Converted to hmm_array: [5, 1, 1, 60.0, 37]
# Raw data received from server: ['7', '1', '0', '110.0', '56']
# Converted to hmm_array: [6, 1, 0, 110.0, 37]
# Raw data received from server: ['8', '2', '0', '120.0', '55']
# Converted to hmm_array: [7, 2, 0, 120.0, 37]
# Raw data received from server: ['9', '3', '0', '130.0', '54']
# Converted to hmm_array: [8, 3, 0, 130.0, 37]
# Raw data received from server: ['10', '4', '0', '140.0', '53']
# Converted to hmm_array: [9, 4, 0, 140.0, 37]
# Raw data received from server: ['11', '5', '0', '150.0', '52']
# Converted to hmm_array: [10, 5, 0, 150.0, 37]
# Raw data received from server: ['12', '6', '0', '160.0', '55']
# Converted to hmm_array: [11, 6, 0, 160.0, 37]
# Raw data received from server: ['13', '7', '0', '170.0', '58']
# Converted to hmm_array: [12, 7, 0, 170.0, 37]
# Raw data received from server: ['14', '8', '0', '180.0', '61']
# Converted to hmm_array: [13, 8, 0, 180.0, 37]
# Raw data received from server: ['15', '9', '0', '190.0', '64']
# Converted to hmm_array: [14, 9, 0, 190.0, 37]
# Raw data received from server: ['16', '9', '1', '200.0', '63']
# Converted to hmm_array: [15, 9, 1, 200.0, 37]
# Raw data received from server: ['17', '9', '2', '210.0', '62']
# Converted to hmm_array: [16, 9, 2, 210.0, 37]
# Raw data received from server: ['18', '9', '3', '220.0', '61']
# Converted to hmm_array: [17, 9, 3, 220.0, 37]
# Raw data received from server: ['19', '9', '4', '230.0', '60']
# Converted to hmm_array: [18, 9, 4, 230.0, 37]
# Raw data received from server: ['20', '9', '3', '240.0', '69']
# Converted to hmm_array: [19, 9, 3, 240.0, 37]
# Raw data received from server: ['21', '9', '2', '250.0', '68']
# Converted to hmm_array: [20, 9, 2, 250.0, 37]
# Raw data received from server: ['22', '9', '1', '260.0', '67']
# Converted to hmm_array: [21, 9, 1, 260.0, 37]
# Raw data received from server: ['23', '8', '1', '310.0', '66']
# Converted to hmm_array: [22, 8, 1, 310.0, 37]
# Raw data received from server: ['24', '7', '1', '320.0', '65']
# Converted to hmm_array: [23, 7, 1, 320.0, 37]
# Raw data received from server: ['25', '6', '1', '330.0', '64']
# Converted to hmm_array: [24, 6, 1, 330.0, 37]
# Raw data received from server: ['26', '5', '1', '340.0', '63']
# Converted to hmm_array: [25, 5, 1, 340.0, 37]
# Raw data received from server: ['27', '5', '2', '350.0', '62']
# Converted to hmm_array: [26, 5, 2, 350.0, 37]
# Raw data received from server: ['28', '5', '3', '360.0', '61']
# Converted to hmm_array: [27, 5, 3, 360.0, 37]
# Raw data received from server: ['29', '5', '4', '370.0', '60']
# Converted to hmm_array: [28, 5, 4, 370.0, 37]
# Raw data received from server: ['30', '5', '3', '380.0', '59']
# Converted to hmm_array: [29, 5, 3, 380.0, 37]
# Raw data received from server: ['31', '5', '2', '390.0', '58']
# Converted to hmm_array: [30, 5, 2, 390.0, 37]
# Raw data received from server: ['32', '5', '1', '400.0', '57']
# Converted to hmm_array: [31, 5, 1, 400.0, 37]
# Raw data received from server: ['33', '6', '1', '410.0', '56']
# Converted to hmm_array: [32, 6, 1, 410.0, 37]
# Raw data received from server: ['34', '7', '1', '420.0', '55']
# Converted to hmm_array: [33, 7, 1, 420.0, 37]
# Raw data received from server: ['35', '8', '1', '430.0', '54']
# Converted to hmm_array: [34, 8, 1, 430.0, 37]
# Raw data received from server: ['36', '9', '1', '440.0', '53']
# Converted to hmm_array: [35, 9, 1, 440.0, 37]
# Raw data received from server: ['37', '9', '2', '450.0', '52']
# Converted to hmm_array: [36, 9, 2, 450.0, 37]
# Raw data received from server: ['38', '9', '3', '460.0', '51']
# Converted to hmm_array: [37, 9, 3, 460.0, 37]
# Raw data received from server: ['39', '9', '4', '470.0', '50']
# Converted to hmm_array: [38, 9, 4, 470.0, 37]
# Raw data received from server: ['40', '9', '5', '480.0', '49']
# Converted to hmm_array: [39, 9, 5, 480.0, 37]
# Raw data received from server: ['41', '9', '6', '500.0', '67']
# Converted to hmm_array: [40, 9, 6, 500.0, 37]
# Raw data received from server: ['42', '9', '7', '510.0', '70']
# Converted to hmm_array: [41, 9, 7, 510.0, 37]
# Raw data received from server: ['43', '9', '8', '520.0', '73']
# Converted to hmm_array: [42, 9, 8, 520.0, 37]
# Raw data received from server: ['44', '9', '9', '530.0', '76']
# Converted to hmm_array: [43, 9, 9, 530.0, 37]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 46
#      43             await asyncio.sleep(1)
#      45 # Start the WebSocket client
# ---> 46 await websocket_client()
#
# Cell In[1], line 12, in websocket_client()
#       9 async with websockets.connect(uri) as websocket:
#      10     while True:
#      11         # Receive one row of data from the server
# ---> 12         data_from_server = await websocket.recv()
#      14         # Print the raw data received from the server
#      15         print(f"Raw data received from server: {data_from_server}")
#
# File ~/Ubuntu/virtualenvs_DockerIMGS/my_jupyter_environment/venv/lib/python3.8/site-packages/websockets/legacy/protocol.py:546, in WebSocketCommonProtocol.recv(self)
#     542 self._pop_message_waiter = pop_message_waiter
#     543 try:
#     544     # If asyncio.wait() is canceled, it doesn't cancel
#     545     # pop_message_waiter and self.transfer_data_task.
# --> 546     await asyncio.wait(
#     547         [pop_message_waiter, self.transfer_data_task],
#     548         return_when=asyncio.FIRST_COMPLETED,
#     549     )
#     550 finally:
#     551     self._pop_message_waiter = None
#
# File /usr/lib/python3.8/asyncio/tasks.py:426, in wait(fs, loop, timeout, return_when)
#     420     warnings.warn("The loop argument is deprecated since Python 3.8, "
#     421                   "and scheduled for removal in Python 3.10.",
#     422                   DeprecationWarning, stacklevel=2)
#     424 fs = {ensure_future(f, loop=loop) for f in set(fs)}
# --> 426 return await _wait(fs, timeout, return_when, loop)
#
# File /usr/lib/python3.8/asyncio/tasks.py:534, in _wait(fs, timeout, return_when, loop)
#     531     f.add_done_callback(_on_completion)
#     533 try:
# --> 534     await waiter
#     535 finally:
#     536     if timeout_handle is not None:
#
# CancelledError:

# %%
import asyncio
import websockets

async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        # Receive one row of data from the server
        data_from_server = await websocket.recv()
        
        # Print the raw data received from the server
        print(f"Raw data received from server: {data_from_server}")
        
        # Parse the received data (convert string to list)
        row = eval(data_from_server)  # Convert string back to list
        
        # Extract data from the row
        first_state = int(row[1])
        second_state = int(row[2])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining  # timestep + steps_remaining
        
        # Append the processed data to SHMM-like structure
        shmm_data = [[timestep, first_state, second_state, steps_remaining, mission_time]]
        
        # Convert the processed data into the hmm_array format
        hmm_array = [timestep, first_state, second_state, round(float(row[3]), 2), 37]  # 37 as a constant value
        
        # Print the converted hmm_array
        print(f"Converted to hmm_array: {hmm_array}")
        
        # Send a confirmation message back to the server
        await websocket.send("Data received and processed")
        
        # Stop after processing the first row
        print("Processing completed. Stopping client.")

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Converted to hmm_array: [0, 4, 3, 10.0, 37]
# Processing completed. Stopping client.

# %%
import asyncio
import websockets
import numpy as np

# Function to generate RMM array based on SHMM-like data
def generate_rmm_array(shmm_data):
    num_tasks = len(shmm_data)

    position_values = [pose[0:2] for pose in shmm_data]  # Assuming first two elements are position (x, y)
    time_values = [pose[3] for pose in shmm_data]        # Assuming the 4th element is time
    mission_time_values = [pose[4] for pose in shmm_data]  # Assuming the 5th element is mission time

    # Increase noise standard deviation
    position_noise = np.random.normal(0, 1, (num_tasks, 2))  # Noise for x and y positions
    time_noise = np.random.normal(0, 3, num_tasks)

    rmm_array = []
    
    for i in range(num_tasks):
        position_value1 = int(np.round(np.abs(position_values[i][0] + position_noise[i][0])))
        position_value2 = int(np.round(np.abs(position_values[i][1] + position_noise[i][1])))
        time_taken = round((time_values[i] + time_noise[i]), 2)
        mission_time = int(mission_time_values[i])

        # Clip position values to be within specified limits
        position_value1 = np.clip(position_value1, 0, 5)
        position_value2 = np.clip(position_value2, 0, 3)

        rmm_array.append([i, position_value1, position_value2, time_taken, mission_time])
    
    return rmm_array

# Function to calculate L1 norm between two arrays
def calculate_l1_norm(array1, array2):
    return np.sum(np.abs(np.array(array2) - np.array(array1)))

# Bayesian update logic
def bayesian_probabilistic_update_general(original_value, deviation, threshold):
    expected_value = original_value + deviation
    updated_value = expected_value if abs(deviation) > threshold else original_value
    return updated_value

# Function to generate delay message based on scenario
def generate_delay_message(robot_number, X, Y, A, B, scenario=None):
    if scenario == "emergency_stop":
        return (
            f"Commander, Robot {robot_number} has encountered an emergency situation "
            f"and has stopped abruptly at position {A}. Further assessment is required.\n"
            "**************************************************\n"
        )
    elif scenario == "obstacle_detected":
        return (
            f"Commander, Robot {robot_number} has detected an obstacle in its path and is navigating around it. "
            f"Current position: {A}.\n"
            "**************************************************\n"
        )
    elif scenario == "low_battery":
        return (
            f"Commander, Robot {robot_number}'s battery level is critically low. "
            f"It will pause its mission and return to base for recharging. Current position: {A}.\n"
            "**************************************************\n"
        )
    elif scenario == "communication_failure":
        return (
            f"Commander, Communication with Robot {robot_number} has been lost. "
            f"Please investigate the issue. Last known position: {A}.\n"
            "**************************************************\n"
        )
    elif scenario == "sensor_malfunction":
        return (
            f"Commander, Robot {robot_number} has experienced a sensor malfunction, affecting its navigation accuracy. "
            f"Current position: {A}.\n"
            "**************************************************\n"
        )
    else:
        time_difference = Y - X
        position_difference = (B[0] - A[0], B[1] - A[1])

        message = "-" * 50 + f"\nCommander,\n\nRobot {robot_number}'s mission status update:\n"
        
        # Time-related message
        if time_difference > 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is currently experiencing a delay of {time_difference} seconds.\n"
            )
        elif time_difference < 0:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is ahead of schedule by {abs(time_difference)} seconds.\n"
            )
        else:
            time_message = (
                f"- Estimated Time of Completion: {X} seconds\n"
                f"- Actual Time of Completion: {Y} seconds\n"
                f"- Expected Coordinates: {A}\n"
                f"- Actual Coordinates: {B}\n\n"
                f"The robot is on schedule.\n"
            )

        # Position-related message
        position_message = f"It is now located at position {B}."
        if any(position_difference):
            position_message += f" It has moved {abs(position_difference[0])} units " \
                               f"to the {'right' if position_difference[0] > 0 else 'left'}"
            position_message += f" and {abs(position_difference[1])} units " \
                               f"{'upward' if position_difference[1] > 0 else 'downward'} " \
                               f"from the expected position ({A})."

        message += time_message + position_message + "\n\n" + "-" * 50
        return message

# Function to generate communication message based on deviation
def generate_communication_message(deviation, threshold, hmm_pos1, hmm_pos2, rmm_pos1, rmm_pos2, hmm_time, rmm_time):
    messages = []
    if abs(deviation) > threshold:
        robot_number = 1  # Example robot number
        X = hmm_time
        Y = rmm_time
        A = (hmm_pos1, hmm_pos2)
        B = (rmm_pos1, rmm_pos2)
        delay_message = generate_delay_message(robot_number, X, Y, A, B)
        messages.append(delay_message)
    return messages

# Main function to process data received from the WebSocket server
async def websocket_client():
    uri = "ws://localhost:8765"
    timestep = 0  # Start with timestep 0

    async with websockets.connect(uri) as websocket:
        data_from_server = await websocket.recv()
        print(f"Raw data received from server: {data_from_server}")

        # Parse the received data
        row = eval(data_from_server)  # Convert string back to list
        first_state = int(row[1])
        second_state = int(row[2])
        steps_remaining = int(row[4])
        mission_time = timestep + steps_remaining

        # Generate SHMM-like data
        shmm_data = [[timestep, first_state, second_state, steps_remaining, mission_time]]
        rmm_arrays = generate_rmm_array(shmm_data)

        # Prepare HMM arrays
        hmm_arrays = [[timestep, first_state, second_state, round(float(row[3]), 2), 37]]  # 37 as a constant value

        # Calculate deviation and generate communication message
        deviation = calculate_l1_norm([hmm_arrays[0][4]], [rmm_arrays[0][4]])
        threshold = 20  # Set a threshold for communication
        messages = generate_communication_message(deviation, threshold, hmm_arrays[0][1], hmm_arrays[0][2], rmm_arrays[0][1], rmm_arrays[0][2], hmm_arrays[0][3], rmm_arrays[0][3])

        # Send communication messages back to the server if any
        for message in messages:
            await websocket.send(message)
            print(f"Sent message to server: {message}")

        print("Processing completed. Stopping client.")

# Start the WebSocket client
asyncio.run(websocket_client())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 168
#     165         print("Processing completed. Stopping client.")
#     167 # Start the WebSocket client
# --> 168 asyncio.run(websocket_client())
#
# File /usr/lib/python3.8/asyncio/runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import asyncio
import websockets

async def websocket_client():
    uri = "ws://localhost:8765"
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        while True:
            # Receive one row of data from the server
            data_from_server = await websocket.recv()
            
            # Print the raw data received from the server
            print(f"Raw data received from server: {data_from_server}")
            
            # Parse the received data (convert string to list)
            row = eval(data_from_server)  # Convert string back to list
            
            # Now process the row to generate hmm_array
            first_state = int(row[1])
            second_state = int(row[2])
            time_elapsed = float(row[3])
            steps_remaining = int(row[4])
            mission_time = int(row[0]) + steps_remaining  # timestep + steps_remaining
                    shmm_data.append(((first_state, second_state), time_elapsed, mission_time))

            # Convert the received data into the hmm_array format
            hmm_array = [int(row[0]), first_state, second_state, round(time_elapsed, 2), mission_time, 37]
            
            # Print the converted hmm_array
            print(f"Converted to hmm_array: {hmm_array}")
            
            # Send a confirmation message back to the server
            await websocket.send("Data received and processed")
            
            # Introduce delay to simulate some processing time
            await asyncio.sleep(1)

# Start the WebSocket client
await websocket_client()
# Out:
# Raw data received from server: ['1', '4', '3', '10.0', '48']
# Converted to hmm_array: [1, 4, 3, 10.0, 49, 37]
# Raw data received from server: ['2', '4', '2', '20.0', '47']
# Converted to hmm_array: [2, 4, 2, 20.0, 49, 37]
# Raw data received from server: ['3', '4', '1', '30.0', '46']
# Converted to hmm_array: [3, 4, 1, 30.0, 49, 37]
# Raw data received from server: ['4', '3', '1', '40.0', '49']
# Converted to hmm_array: [4, 3, 1, 40.0, 53, 37]
# Raw data received from server: ['5', '2', '1', '50.0', '52']
# Converted to hmm_array: [5, 2, 1, 50.0, 57, 37]
# Raw data received from server: ['6', '1', '1', '60.0', '55']
# Converted to hmm_array: [6, 1, 1, 60.0, 61, 37]
# Raw data received from server: ['7', '1', '0', '110.0', '56']
# Converted to hmm_array: [7, 1, 0, 110.0, 63, 37]
# Raw data received from server: ['8', '2', '0', '120.0', '55']
# Converted to hmm_array: [8, 2, 0, 120.0, 63, 37]
# Raw data received from server: ['9', '3', '0', '130.0', '54']
# Converted to hmm_array: [9, 3, 0, 130.0, 63, 37]
# Raw data received from server: ['10', '4', '0', '140.0', '53']
# Converted to hmm_array: [10, 4, 0, 140.0, 63, 37]
# Raw data received from server: ['11', '5', '0', '150.0', '52']
# Converted to hmm_array: [11, 5, 0, 150.0, 63, 37]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 39
#      36             await asyncio.sleep(1)
#      38 # Start the WebSocket client
# ---> 39 await websocket_client()
#
# Cell In[2], line 11, in websocket_client()
#       8 async with websockets.connect(uri) as websocket:
#       9     while True:
#      10         # Receive one row of data from the server
# ---> 11         data_from_server = await websocket.recv()
#      13         # Print the raw data received from the server
#      14         print(f"Raw data received from server: {data_from_server}")
#
# File ~/Ubuntu/virtualenvs_DockerIMGS/my_jupyter_environment/venv/lib/python3.8/site-packages/websockets/legacy/protocol.py:546, in WebSocketCommonProtocol.recv(self)
#     542 self._pop_message_waiter = pop_message_waiter
#     543 try:
#     544     # If asyncio.wait() is canceled, it doesn't cancel
#     545     # pop_message_waiter and self.transfer_data_task.
# --> 546     await asyncio.wait(
#     547         [pop_message_waiter, self.transfer_data_task],
#     548         return_when=asyncio.FIRST_COMPLETED,
#     549     )
#     550 finally:
#     551     self._pop_message_waiter = None
#
# File /usr/lib/python3.8/asyncio/tasks.py:426, in wait(fs, loop, timeout, return_when)
#     420     warnings.warn("The loop argument is deprecated since Python 3.8, "
#     421                   "and scheduled for removal in Python 3.10.",
#     422                   DeprecationWarning, stacklevel=2)
#     424 fs = {ensure_future(f, loop=loop) for f in set(fs)}
# --> 426 return await _wait(fs, timeout, return_when, loop)
#
# File /usr/lib/python3.8/asyncio/tasks.py:534, in _wait(fs, timeout, return_when, loop)
#     531     f.add_done_callback(_on_completion)
#     533 try:
# --> 534     await waiter
#     535 finally:
#     536     if timeout_handle is not None:
#
# CancelledError:

# %%
import asyncio
import websockets

async def websocket_client():
    uri = "ws://localhost:8765"
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        while True:
            # Receive one row of data from the server
            data_from_server = await websocket.recv()
            
            # Parse the received data (convert string to list)
            row = eval(data_from_server)  # Convert string back to list
            
            # Now process the row to generate hmm_array
            first_state = int(row[1])
            second_state = int(row[2])
            time_elapsed = float(row[3])
            steps_remaining = int(row[4])
            mission_time = int(row[0]) + steps_remaining  # timestep + steps_remaining
            
            # Convert the received data into the hmm_array format
            hmm_array = [int(row[0]), first_state, second_state, round(time_elapsed, 2), mission_time, 37]
            
            # Print the converted hmm_array
            print(f"Converted to hmm_array: {hmm_array}")
            
            # Send a confirmation message back to the server
            await websocket.send("Data received and processed")
            
            # Introduce delay to simulate some processing time
            await asyncio.sleep(1)

# Start the WebSocket client
await websocket_client()
# Out:
# Converted to hmm_array: [1, 4, 3, 10.0, 49, 37]
# Converted to hmm_array: [2, 4, 2, 20.0, 49, 37]
# Converted to hmm_array: [3, 4, 1, 30.0, 49, 37]
# Converted to hmm_array: [4, 3, 1, 40.0, 53, 37]
# Converted to hmm_array: [5, 2, 1, 50.0, 57, 37]
# Converted to hmm_array: [6, 1, 1, 60.0, 61, 37]
# Converted to hmm_array: [7, 1, 0, 110.0, 63, 37]
# Converted to hmm_array: [8, 2, 0, 120.0, 63, 37]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 36
#      33             await asyncio.sleep(1)
#      35 # Start the WebSocket client
# ---> 36 await websocket_client()
#
# Cell In[1], line 33, in websocket_client()
#      30 await websocket.send("Data received and processed")
#      32 # Introduce delay to simulate some processing time
# ---> 33 await asyncio.sleep(1)
#
# File /usr/lib/python3.8/asyncio/tasks.py:659, in sleep(delay, result, loop)
#     655 h = loop.call_later(delay,
#     656                     futures._set_result_unless_cancelled,
#     657                     future, result)
#     658 try:
# --> 659     return await future
#     660 finally:
#     661     h.cancel()
#
# CancelledError:

# %%
import asyncio
import websockets
import time

async def websocket_client():
    uri = "ws://localhost:8765"
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        timestep = 0
        
        while True:
            # Receive data from the server
            data_from_server = await websocket.recv()
            
            # Split the received data to extract individual elements
            row = data_from_server.split(',')
            first_state = int(row[1])
            second_state = int(row[2])
            time_elapsed = float(row[3])
            steps_remaining = int(row[4])
            mission_time = timestep + steps_remaining
            
            # Convert the received data to the hmm_array format
            hmm_array = [timestep, first_state, second_state, round(time_elapsed, 2), 37]
            timestep += 1
            
            # Print the formatted hmm_array
            print(f"Converted to hmm_array: {hmm_array}")
            
            # Send acknowledgment to the server
            await websocket.send(f"Data received: {hmm_array}")
            
            # Wait for 1 second before the next iteration
            await asyncio.sleep(1)

await websocket_client()
# Out:
# ---------------------------------------------------------------------------
# ConnectionClosedError                     Traceback (most recent call last)
# Cell In[1], line 37
#      34             # Wait for 1 second before the next iteration
#      35             await asyncio.sleep(1)
# ---> 37 await websocket_client()
#
# Cell In[1], line 14, in websocket_client()
#      10 timestep = 0
#      12 while True:
#      13     # Receive data from the server
# ---> 14     data_from_server = await websocket.recv()
#      16     # Split the received data to extract individual elements
#      17     row = data_from_server.split(',')
#
# File ~/Ubuntu/virtualenvs_DockerIMGS/my_jupyter_environment/venv/lib/python3.8/site-packages/websockets/legacy/protocol.py:562, in WebSocketCommonProtocol.recv(self)
#     558             return None  # type: ignore
#     559         else:
#     560             # Wait until the connection is closed to raise
#     561             # ConnectionClosed with the correct code and reason.
# --> 562             await self.ensure_open()
#     564 # Pop a message from the queue.
#     565 message = self.messages.popleft()
#
# File ~/Ubuntu/virtualenvs_DockerIMGS/my_jupyter_environment/venv/lib/python3.8/site-packages/websockets/legacy/protocol.py:938, in WebSocketCommonProtocol.ensure_open(self)
#     931 if self.state is State.CLOSING:
#     932     # If we started the closing handshake, wait for its completion to
#     933     # get the proper close code and reason. self.close_connection_task
#     934     # will complete within 4 or 5 * close_timeout after close(). The
#     935     # CLOSING state also occurs when failing the connection. In that
#     936     # case self.close_connection_task will complete even faster.
#     937     await asyncio.shield(self.close_connection_task)
# --> 938     raise self.connection_closed_exc()
#     940 # Control may only reach this point in buggy third-party subclasses.
#     941 assert self.state is State.CONNECTING
#
# ConnectionClosedError: received 1011 (internal error); then sent 1011 (internal error)

# %%
# Client

import asyncio
import websockets
import time

async def websocket_client():
    uri = "ws://localhost:8765"
    
    # Connect to the server
    async with websockets.connect(uri) as websocket:
        while True:
            start_time = time.time()

            data_from_server = await websocket.recv()
            
            end_time = time.time()

            elapsed_time = end_time - start_time
            
            # Print the received data along with the time it took
            print(f"Received from server: {data_from_server}")
            print(f"Time taken to receive data: {elapsed_time:.4f} seconds")
            
            await websocket.send("Data received")
            
            await asyncio.sleep(1)

await websocket_client()
